# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %% [markdown]
# `pickle` is a Python utility module used to save any Python object or data structure on to disk. Pickle will do something special called serialization. It converts any Python object or in this case,
# this twitter_keys object, in to a character stream so the object can be recreated later in Python when we need it. Reconstruction of that object is called deserialization.
#
# Below we create an object called `twitter_keys` and use it to store our Twitter API access credentials. If the pickled credentials exist, it will just load the credentials from the pickle file in to the twitter_keys object.
#
# The pickle `.dump(obj, file)` method writes the pickled representation of the object 'obj' to the open file object 'file'. We use 'wb' as we're writing as byte data. This is required for serialization.
#
# The pickle `.load(file)` method reads the pickled (serialized) representation of an object from the open file object 'file; and returns the reconstituted object hierarchy specified therein (deserialized object).

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    twitter_keys={}
    twitter_keys['Consumer Key'] = ''
    twitter_keys['Consumer Secret'] = ''
    twitter_keys['Access Token'] = ''
    twitter_keys['Access Token Secret'] = ''
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(twitter_keys, f)
else:
    twitter_keys=pickle.load(open('secret_twitter_credentials.pkl','rb'))
# twitter_keys

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\programdata\anaconda3\lib\site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
# Remember, using ? before a library pulls up documentation for that library (very handy!)
# ?twitter

# %% [markdown]
# Using our twitter authorization object below, we create a Twitter API object which we can then use to access data via the Twitter API.
#
# For reference: Twitter API objects are created as: t = Twitter(
#         auth=OAuth(token, token_secret, consumer_key, consumer_secret))

# %%
import twitter

auth = twitter.oauth.OAuth(twitter_keys['Access Token'],
                           twitter_keys['Access Token Secret'],
                           twitter_keys['Consumer Key'],
                           twitter_keys['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a defined variable that
# represents a Twitter API object.
print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x000000515F6DB7B8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# Look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/
#
# **Note: None of these links work as of Nov 2019.**

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %% [markdown]
# Using our twitter_api object, we use the `.trends` method, specifying by location, to find the current top 50 trends for each given WOE id.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization. Without the underscore, the
# twitter package appends the ID value to the URL itself as a special case keyword argument
# (results in an error).

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %% [markdown]
# Our returned response is in `JSON` (file format that internet applications use to communicate semi-structured information).

# %%
world_trends[0]
# Out:
# {'trends': [{'name': '#BlinksCallOutYG',
#    'url': 'http://twitter.com/search?q=%23BlinksCallOutYG',
#    'promoted_content': None,
#    'query': '%23BlinksCallOutYG',
#    'tweet_volume': 161347},
#   {'name': '#oimo',
#    'url': 'http://twitter.com/search?q=%23oimo',
#    'promoted_content': None,
#    'query': '%23oimo',
#    'tweet_volume': 17212},
#   {'name': '#نفسيا_احتاج',
#    'url': 'http://twitter.com/search?q=%23%D9%86%D9%81%D8%B3%D9%8A%D8%A7_%D8%A7%D8%AD%D8%AA%D8%A7%D8%AC',
#    'promoted_content': None,
#    'query': '%23%D9%86%D9%81%D8%B3%D9%8A%D8%A7_%D8%A7%D8%AD%D8%AA%D8%A7%D8%AC',
#    'tweet_volume': 22340},
#   {'name': '#USMNT',
#    'url': 'http://twitter.com/search?q=%23USMNT',
#    'promoted_content': None,
#    'query': '%23USMNT',
#    'tweet_volume': None},
#   {'name': '#MostAnnoyingThingAboutTwitter',
#    'url': 'http://twitter.com/search?q=%23MostAnnoyingThingAboutTwitter',
#    'promoted_content': None,
#    'query': '%23MostAnnoyingThingAboutTwitter',
#    'tweet_volume': None},
#   {'name': 'Ana Furtado',
#    'url': 'http://twitter.com/search?q=%22Ana+Furtado%22',
#    'promoted_content': None,
#    'query': '%22Ana+Furtado%22',
#    'tweet_volume': None},
#   {'name': 'Tre Jones',
#    'url': 'http://twitter.com/search?q=%22Tre+Jones%22',
#    'promoted_content': None,
#    'query': '%22Tre+Jones%22',
#    'tweet_volume': None},
#   {'name': 'ESTUDIE VAGA',
#    'url': 'http://twitter.com/search?q=%22ESTUDIE+VAGA%22',
#    'promoted_content': None,
#    'query': '%22ESTUDIE+VAGA%22',
#    'tweet_volume': None},
#   {'name': 'Artículo 1',
#    'url': 'http://twitter.com/search?q=%22Art%C3%ADculo+1%22',
#    'promoted_content': None,
#    'query': '%22Art%C3%ADculo+1%22',
#    'tweet_volume': 20757},
#   {'name': 'Nicolas Cage',
#    'url': 'http://twitter.com/search?q=%22Nicolas+Cage%22',
#    'promoted_content': None,
#    'query': '%22Nicolas+Cage%22',
#    'tweet_volume': None},
#   {'name': 'Jabbawockeez',
#    'url': 'http://twitter.com/search?q=Jabbawockeez',
#    'promoted_content': None,
#    'query': 'Jabbawockeez',
#    'tweet_volume': 65632},
#   {'name': 'Voluntad Popular',
#    'url': 'http://twitter.com/search?q=%22Voluntad+Popular%22',
#    'promoted_content': None,
#    'query': '%22Voluntad+Popular%22',
#    'tweet_volume': 33508},
#   {'name': 'メタモン厳選',
#    'url': 'http://twitter.com/search?q=%E3%83%A1%E3%82%BF%E3%83%A2%E3%83%B3%E5%8E%B3%E9%81%B8',
#    'promoted_content': None,
#    'query': '%E3%83%A1%E3%82%BF%E3%83%A2%E3%83%B3%E5%8E%B3%E9%81%B8',
#    'tweet_volume': None},
#   {'name': 'UNIDOS PELO DIEGO',
#    'url': 'http://twitter.com/search?q=%22UNIDOS+PELO+DIEGO%22',
#    'promoted_content': None,
#    'query': '%22UNIDOS+PELO+DIEGO%22',
#    'tweet_volume': 23948},
#   {'name': 'Zardes',
#    'url': 'http://twitter.com/search?q=Zardes',
#    'promoted_content': None,
#    'query': 'Zardes',
#    'tweet_volume': None},
#   {'name': 'RESPECT EMILIO',
#    'url': 'http://twitter.com/search?q=%22RESPECT+EMILIO%22',
#    'promoted_content': None,
#    'query': '%22RESPECT+EMILIO%22',
#    'tweet_volume': None},
#   {'name': '#aikatsu',
#    'url': 'http://twitter.com/search?q=%23aikatsu',
#    'promoted_content': None,
#    'query': '%23aikatsu',
#    'tweet_volume': 20616},
#   {'name': '#FreeCodeFridayContest',
#    'url': 'http://twitter.com/search?q=%23FreeCodeFridayContest',
#    'promoted_content': None,
#    'query': '%23FreeCodeFridayContest',
#    'tweet_volume': 14016},
#   {'name': '#MaskSinger',
#    'url': 'http://twitter.com/search?q=%23MaskSinger',
#    'promoted_content': None,
#    'query': '%23MaskSinger',
#    'tweet_volume': 34613},
#   {'name': '#بوح_اخر_الليل',
#    'url': 'http://twitter.com/search?q=%23%D8%A8%D9%88%D8%AD_%D8%A7%D8%AE%D8%B1_%D8%A7%D9%84%D9%84%D9%8A%D9%84',
#    'promoted_content': None,
#    'query': '%23%D8%A8%D9%88%D8%AD_%D8%A7%D8%AE%D8%B1_%D8%A7%D9%84%D9%84%D9%8A%D9%84',
#    'tweet_volume': None},
#   {'name': '#AhmetKaya',
#    'url': 'http://twitter.com/search?q=%23AhmetKaya',
#    'promoted_content': None,
#    'query': '%23AhmetKaya',
#    'tweet_volume': None},
#   {'name': '#ResignNowTrump',
#    'url': 'http://twitter.com/search?q=%23ResignNowTrump',
#    'promoted_content': None,
#    'query': '%23ResignNowTrump',
#    'tweet_volume': 52666},
#   {'name': '#Russ',
#    'url': 'http://twitter.com/search?q=%23Russ',
#    'promoted_content': None,
#    'query': '%23Russ',
#    'tweet_volume': None},
#   {'name': '#laluchasigue',
#    'url': 'http://twitter.com/search?q=%23laluchasigue',
#    'promoted_content': None,
#    'query': '%23laluchasigue',
#    'tweet_volume': 53262},
#   {'name': '#EstoNoHaTerminado',
#    'url': 'http://twitter.com/search?q=%23EstoNoHaTerminado',
#    'promoted_content': None,
#    'query': '%23EstoNoHaTerminado',
#    'tweet_volume': 64843},
#   {'name': '#DearMyIZONE',
#    'url': 'http://twitter.com/search?q=%23DearMyIZONE',
#    'promoted_content': None,
#    'query': '%23DearMyIZONE',
#    'tweet_volume': None},
#   {'name': '#suspendRudolph',
#    'url': 'http://twitter.com/search?q=%23suspendRudolph',
#    'promoted_content': None,
#    'query': '%23suspendRudolph',
#    'tweet_volume': None},
#   {'name': '#とんがらし麺と優勝予想ウメブラSP7',
#    'url': 'http://twitter.com/search?q=%23%E3%81%A8%E3%82%93%E3%81%8C%E3%82%89%E3%81%97%E9%BA%BA%E3%81%A8%E5%84%AA%E5%8B%9D%E4%BA%88%E6%83%B3%E3%82%A6%E3%83%A1%E3%83%96%E3%83%A9SP7',
#    'promoted_content': None,
#    'query': '%23%E3%81%A8%E3%82%93%E3%81%8C%E3%82%89%E3%81%97%E9%BA%BA%E3%81%A8%E5%84%AA%E5%8B%9D%E4%BA%88%E6%83%B3%E3%82%A6%E3%83%A1%E3%83%96%E3%83%A9SP7',
#    'tweet_volume': None},
#   {'name': '#ÖrtümeDokunanEliKırarım',
#    'url': 'http://twitter.com/search?q=%23%C3%96rt%C3%BCmeDokunanEliK%C4%B1rar%C4%B1m',
#    'promoted_content': None,
#    'query': '%23%C3%96rt%C3%BCmeDokunanEliK%C4%B1rar%C4%B1m',
#    'tweet_volume': 31849},
#   {'name': '#صندوق_الجيش',
#    'url': 'http://twitter.com/search?q=%23%D8%B5%D9%86%D8%AF%D9%88%D9%82_%D8%A7%D9%84%D8%AC%D9%8A%D8%B4',
#    'promoted_content': None,
#    'query': '%23%D8%B5%D9%86%D8%AF%D9%88%D9%82_%D8%A7%D9%84%D8%AC%D9%8A%D8%B4',
#    'tweet_volume': 10852},
#   {'name': '#ExtortAFilm',
#    'url': 'http://twitter.com/search?q=%23ExtortAFilm',
#    'promoted_content': None,
#    'query': '%23ExtortAFilm',
#    'tweet_volume': None},
#   {'name': '#GolpeDeEstadoEnBoliva',
#    'url': 'http://twitter.com/search?q=%23GolpeDeEstadoEnBoliva',
#    'promoted_content': None,
#    'query': '%23GolpeDeEstadoEnBoliva',
#    'tweet_volume': None},
#   {'name': '#ウルトラマンタイガ',
#    'url': 'http://twitter.com/search?q=%23%E3%82%A6%E3%83%AB%E3%83%88%E3%83%A9%E3%83%9E%E3%83%B3%E3%82%BF%E3%82%A4%E3%82%AC',
#    'promoted_content': None,
#    'query': '%23%E3%82%A6%E3%83%AB%E3%83%88%E3%83%A9%E3%83%9E%E3%83%B3%E3%82%BF%E3%82%A4%E3%82%AC',
#    'tweet_volume': None},
#   {'name': '#boltonfire',
#    'url': 'http://twitter.com/search?q=%23boltonfire',
#    'promoted_content': None,
#    'query': '%23boltonfire',
#    'tweet_volume': None},
#   {'name': '#GHVIP16N',
#    'url': 'http://twitter.com/search?q=%23GHVIP16N',
#    'promoted_content': None,
#    'query': '%23GHVIP16N',
#    'tweet_volume': None},
#   {'name': '#البراد_هب_ويبيله',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%A8%D8%B1%D8%A7%D8%AF_%D9%87%D8%A8_%D9%88%D9%8A%D8%A8%D9%8A%D9%84%D9%87',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%84%D8%A8%D8%B1%D8%A7%D8%AF_%D9%87%D8%A8_%D9%88%D9%8A%D8%A8%D9%8A%D9%84%D9%87',
#    'tweet_volume': None},
#   {'name': '#lovesyourass',
#    'url': 'http://twitter.com/search?q=%23lovesyourass',
#    'promoted_content': None,
#    'query': '%23lovesyourass',
#    'tweet_volume': None},
#   {'name': '#ايران_تنتفض',
#    'url': 'http://twitter.com/search?q=%23%D8%A7%D9%8A%D8%B1%D8%A7%D9%86_%D8%AA%D9%86%D8%AA%D9%81%D8%B6',
#    'promoted_content': None,
#    'query': '%23%D8%A7%D9%8A%D8%B1%D8%A7%D9%86_%D8%AA%D9%86%D8%AA%D9%81%D8%B6',
#    'tweet_volume': 12973},
#   {'name': '#FightingForWonho',
#    'url': 'http://twitter.com/search?q=%23FightingForWonho',
#    'promoted_content': None,
#    'query': '%23FightingForWonho',
#    'tweet_volume': 247827},
#   {'name': '#PlazaDignidad',
#    'url': 'http://twitter.com/search?q=%23PlazaDignidad',
#    'promoted_content': None,
#    'query': '%23PlazaDignidad',
#    'tweet_volume': 10517},
#   {'name': '#ChildrenInNeed',
#    'url': 'http://twitter.com/search?q=%23ChildrenInNeed',
#    'promoted_content': None,
#    'query': '%23ChildrenInNeed',
#    'tweet_volume': 41551},
#   {'name': '#GilmarMendesVairCair',
#    'url': 'http://twitter.com/search?q=%23GilmarMendesVairCair',
#    'promoted_content': None,
#    'query': '%23GilmarMendesVairCair',
#    'tweet_volume': 32817},
#   {'name': '#CrisisOnInfiniteEarths',
#    'url': 'http://twitter.com/search?q=%23CrisisOnInfiniteEarths',
#    'promoted_content': None,
#    'query': '%23CrisisOnInfiniteEarths',
#    'tweet_volume': None},
#   {'name': '#propagandalive',
#    'url': 'http://twitter.com/search?q=%23propagandalive',
#    'promoted_content': None,
#    'query': '%23propagandalive',
#    'tweet_volume': None},
#   {'name': '#BajarRemuneracionParlamento',
#    'url': 'http://twitter.com/search?q=%23BajarRemuneracionParlamento',
#    'promoted_content': None,
#    'query': '%23BajarRemuneracionParlamento',
#    'tweet_volume': 11707},
#   {'name': '#lovefortheclique',
#    'url': 'http://twitter.com/search?q=%23lovefortheclique',
#    'promoted_content': None,
#    'query': '%23lovefortheclique',
#    'tweet_volume': None},
#   {'name': '#RectaFinal',
#    'url': 'http://twitter.com/search?q=%23RectaFinal',
#    'promoted_content': None,
#    'query': '%23RectaFinal',
#    'tweet_volume': None},
#   {'name': '#MilenioLive',
#    'url': 'http://twitter.com/search?q=%23MilenioLive',
#    'promoted_content': None,
#    'query': '%23MilenioLive',
#    'tweet_volume': None},
#   {'name': '#SuperM_TENinAtlanta',
#    'url': 'http://twitter.com/search?q=%23SuperM_TENinAtlanta',
#    'promoted_content': None,
#    'query': '%23SuperM_TENinAtlanta',
#    'tweet_volume': 14771},
#   {'name': '#VoyADejarDeFumar',
#    'url': 'http://twitter.com/search?q=%23VoyADejarDeFumar',
#    'promoted_content': None,
#    'query': '%23VoyADejarDeFumar',
#    'tweet_volume': None}],
#  'as_of': '2019-11-16T01:53:11Z',
#  'created_at': '2019-11-16T01:49:55Z',
#  'locations': [{'name': 'Worldwide', 'woeid': 1}]}

# %% [markdown]
# Below we see that our `.trends` call on our Twitter API object returns a TwitterListResponse object. The object is similar to a python dictionary. By using the `.keys()` method and returning as a Python list, we can see the keys of the dictionary.
#
# Most of the keys have an easy to read value. 'as_of' and 'created_at' are simply date strings. 'locations' is a small dictionary containing name of the location and it's woeid. 'trends' however is a large list of dictionaries. Each dictionary entry of the list contains the name of the trending tweet, url and tweet_volume, among other things.

# %%
trends=local_trends

print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#FreeCodeFridayContest', 'url': 'http://twitter.com/search?q=%23FreeCodeFridayContest', 'promoted_content': None, 'query': '%23FreeCodeFridayContest', 'tweet_volume': 13994}, {'name': '#ImpeachingHearings', 'url': 'http://twitter.com/search?q=%23ImpeachingHearings', 'promoted_content': None, 'query': '%23ImpeachingHearings', 'tweet_volume': 171684}, {'name': 'Stone', 'url': 'http://twitter.com/search?q=Stone', 'promoted_content': None, 'query': 'Stone', 'tweet_volume': 729393}, {'name': 'Rudolph', 'url': 'http://twitter.com/search?q=Rudolph', 'promoted_content': None, 'query': 'Rudolph', 'tweet_volume': 548857}, {'name': 'Myles', 'url': 'http://twitter.com/search?q=Myles', 'promoted_content': None, 'query': 'Myles', 'tweet_volume': 790261}, {'name': 'Mason', 'url': 'http://twitter.com/search?q=Mason', 'promoted_content': None, 'query': 'Mason', 'tweet_volume': 470719}, {'name': '#USMNT', 'url': 'http://twitter.com/search?q=%23USMNT', 'promoted_content': None, 'query': '%23USMNT', 'tweet_volume': None}, {'name': '#MostAnnoyingThingAboutTwitter', 'url': 'http://twitter.com/search?q=%23MostAnnoyingThingAboutTwitter', 'promoted_content': None, 'query': '%23MostAnnoyingThingAboutTwitter', 'tweet_volume': None}, {'name': 'Tre Jones', 'url': 'http://twitter.com/search?q=%22Tre+Jones%22', 'promoted_content': None, 'query': '%22Tre+Jones%22', 'tweet_volume': None}, {'name': '#ResignNowTrump', 'url': 'http://twitter.com/search?q=%23ResignNowTrump', 'promoted_content': None, 'query': '%23ResignNowTrump', 'tweet_volume': 51910}, {'name': 'David Holmes', 'url': 'http://twitter.com/search?q=%22David+Holmes%22', 'promoted_content': None, 'query': '%22David+Holmes%22', 'tweet_volume': 43494}, {'name': 'Nicolas Cage', 'url': 'http://twitter.com/search?q=%22Nicolas+Cage%22', 'promoted_content': None, 'query': '%22Nicolas+Cage%22', 'tweet_volume': None}, {'name': 'Jordan Morris', 'url': 'http://twitter.com/search?q=%22Jordan+Morris%22', 'promoted_content': None, 'query': '%22Jordan+Morris%22', 'tweet_volume': None}, {'name': 'Zardes', 'url': 'http://twitter.com/search?q=Zardes', 'promoted_content': None, 'query': 'Zardes', 'tweet_volume': None}, {'name': 'Jabbawockeez', 'url': 'http://twitter.com/search?q=Jabbawockeez', 'promoted_content': None, 'query': 'Jabbawockeez', 'tweet_volume': 64754}, {'name': 'End 1st', 'url': 'http://twitter.com/search?q=%22End+1st%22', 'promoted_content': None, 'query': '%22End+1st%22', 'tweet_volume': None}, {'name': 'Shorty G', 'url': 'http://twitter.com/search?q=%22Shorty+G%22', 'promoted_content': None, 'query': '%22Shorty+G%22', 'tweet_volume': None}, {'name': 'Joey Baker', 'url': 'http://twitter.com/search?q=%22Joey+Baker%22', 'promoted_content': None, 'query': '%22Joey+Baker%22', 'tweet_volume': None}, {'name': 'Rick Santorum', 'url': 'http://twitter.com/search?q=%22Rick+Santorum%22', 'promoted_content': None, 'query': '%22Rick+Santorum%22', 'tweet_volume': None}, {'name': 'Yelich', 'url': 'http://twitter.com/search?q=Yelich', 'promoted_content': None, 'query': 'Yelich', 'tweet_volume': None}, {'name': 'Universal Championship', 'url': 'http://twitter.com/search?q=%22Universal+Championship%22', 'promoted_content': None, 'query': '%22Universal+Championship%22', 'tweet_volume': None}, {'name': 'Da Baby', 'url': 'http://twitter.com/search?q=%22Da+Baby%22', 'promoted_content': None, 'query': '%22Da+Baby%22', 'tweet_volume': 96514}, {'name': 'Aaron Long', 'url': 'http://twitter.com/search?q=%22Aaron+Long%22', 'promoted_content': None, 'query': '%22Aaron+Long%22', 'tweet_volume': None}, {'name': 'Samsonov', 'url': 'http://twitter.com/search?q=Samsonov', 'promoted_content': None, 'query': 'Samsonov', 'tweet_volume': None}, {'name': 'Drouin', 'url': 'http://twitter.com/search?q=Drouin', 'promoted_content': None, 'query': 'Drouin', 'tweet_volume': None}, {'name': 'ABDC', 'url': 'http://twitter.com/search?q=ABDC', 'promoted_content': None, 'query': 'ABDC', 'tweet_volume': 23010}, {'name': 'Tedra Cobb', 'url':  ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %% [markdown]
# Currently our returned data is quite messy and hard to read. By importing the `json` module and using its `.dumps(obj, indent)` (dump string) method, we get a clearer picture of how the data is structured. The obj argument is serialized to a JSON formatted str.

# %%
import json

print((json.dumps(us_trends[0], indent=1)))
# Out:
# {
#  "trends": [
#   {
#    "name": "#USMNT",
#    "url": "http://twitter.com/search?q=%23USMNT",
#    "promoted_content": null,
#    "query": "%23USMNT",
#    "tweet_volume": null
#   },
#   {
#    "name": "#MostAnnoyingThingAboutTwitter",
#    "url": "http://twitter.com/search?q=%23MostAnnoyingThingAboutTwitter",
#    "promoted_content": null,
#    "query": "%23MostAnnoyingThingAboutTwitter",
#    "tweet_volume": null
#   },
#   {
#    "name": "#FreeCodeFridayContest",
#    "url": "http://twitter.com/search?q=%23FreeCodeFridayContest",
#    "promoted_content": null,
#    "query": "%23FreeCodeFridayContest",
#    "tweet_volume": 14016
#   },
#   {
#    "name": "#ResignNowTrump",
#    "url": "http://twitter.com/search?q=%23ResignNowTrump",
#    "promoted_content": null,
#    "query": "%23ResignNowTrump",
#    "tweet_volume": 52666
#   },
#   {
#    "name": "Tre Jones",
#    "url": "http://twitter.com/search?q=%22Tre+Jones%22",
#    "promoted_content": null,
#    "query": "%22Tre+Jones%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "#suspendRUDOLPH",
#    "url": "http://twitter.com/search?q=%23suspendRUDOLPH",
#    "promoted_content": null,
#    "query": "%23suspendRUDOLPH",
#    "tweet_volume": null
#   },
#   {
#    "name": "David Holmes",
#    "url": "http://twitter.com/search?q=%22David+Holmes%22",
#    "promoted_content": null,
#    "query": "%22David+Holmes%22",
#    "tweet_volume": 44038
#   },
#   {
#    "name": "Nicolas Cage",
#    "url": "http://twitter.com/search?q=%22Nicolas+Cage%22",
#    "promoted_content": null,
#    "query": "%22Nicolas+Cage%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Jabbawockeez",
#    "url": "http://twitter.com/search?q=Jabbawockeez",
#    "promoted_content": null,
#    "query": "Jabbawockeez",
#    "tweet_volume": 65632
#   },
#   {
#    "name": "Zardes",
#    "url": "http://twitter.com/search?q=Zardes",
#    "promoted_content": null,
#    "query": "Zardes",
#    "tweet_volume": null
#   },
#   {
#    "name": "Jordan Morris",
#    "url": "http://twitter.com/search?q=%22Jordan+Morris%22",
#    "promoted_content": null,
#    "query": "%22Jordan+Morris%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "End 1st",
#    "url": "http://twitter.com/search?q=%22End+1st%22",
#    "promoted_content": null,
#    "query": "%22End+1st%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Shorty G",
#    "url": "http://twitter.com/search?q=%22Shorty+G%22",
#    "promoted_content": null,
#    "query": "%22Shorty+G%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Rick Santorum",
#    "url": "http://twitter.com/search?q=%22Rick+Santorum%22",
#    "promoted_content": null,
#    "query": "%22Rick+Santorum%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Joey Baker",
#    "url": "http://twitter.com/search?q=%22Joey+Baker%22",
#    "promoted_content": null,
#    "query": "%22Joey+Baker%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Yelich",
#    "url": "http://twitter.com/search?q=Yelich",
#    "promoted_content": null,
#    "query": "Yelich",
#    "tweet_volume": null
#   },
#   {
#    "name": "Universal Championship",
#    "url": "http://twitter.com/search?q=%22Universal+Championship%22",
#    "promoted_content": null,
#    "query": "%22Universal+Championship%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Da Baby",
#    "url": "http://twitter.com/search?q=%22Da+Baby%22",
#    "promoted_content": null,
#    "query": "%22Da+Baby%22",
#    "tweet_volume": 97533
#   },
#   {
#    "name": "King Corbin",
#    "url": "http://twitter.com/search?q=%22King+Corbin%22",
#    "promoted_content": null,
#    "query": "%22King+Corbin%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Drouin",
#    "url": "http://twitter.com/search?q=Drouin",
#    "promoted_content": null,
#    "query": "Drouin",
#    "tweet_volume": null
#   },
#   {
#    "name": "Samsonov",
#    "url": "http://twitter.com/search?q=Samsonov",
#    "promoted_content": null,
#    "query": "Samsonov",
#    "tweet_volume": null
#   },
#   {
#    "name": "Aaron Long",
#    "url": "http://twitter.com/search?q=%22Aaron+Long%22",
#    "promoted_content": null,
#    "query": "%22Aaron+Long%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Tedra Cobb",
#    "url": "http://twitter.com/search?q=%22Tedra+Cobb%22",
#    "promoted_content": null,
#    "query": "%22Tedra+Cobb%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "ABDC",
#    "url": "http://twitter.com/search?q=ABDC",
#    "promoted_content": null,
#    "query": "ABDC",
#    "tweet_volume": 23402
#   },
#   {
#    "name": "Dest",
#    "url": "http://twitter.com/search?q=Dest",
#    "promoted_content": null,
#    "query": "Dest",
#    "tweet_volume": null
#   },
#   {
#    "name": "Elise",
#    "url": "http://twitter.com/search?q=Elise",
#    "promoted_content": null,
#    "query": "Elise",
#    "tweet_volume": 113615
#   },
#   {
#    "name": "Best Harrie",
#    "url": "http://twitter.com/search?q=%22Best+Harrie%22",
#    "promoted_content": null,
#    "query": "%22Best+Harrie%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Isaiah Moss",
#    "url": "http://twitter.com/search?q=%22Isaiah+Moss%22",
#    "promoted_content": null,
#    "query": "%22Isaiah+Moss%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "Mo Wagner",
#    "url": "http://twitter.com/search?q=%22Mo+Wagner%22",
#    "promoted_content": null,
#    "query": "%22Mo+Wagner%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "John Brooks",
#    "url": "http://twitter.com/search?q=%22John+Brooks%22",
#    "promoted_content": null,
#    "query": "%22John+Brooks%22",
#    "tweet_volume": null
#   },
#   {
#    "name": "#ExtortAFilm",
#    "url": "http://twitter.com/search?q=%23ExtortAFilm",
#    "promoted_content": null,
#    "query": "%23ExtortAFilm",
#    "tweet_volume": null
#   },
#   {
#    "name": "#lovesyourass",
#    "url": "http://twitter.com/search?q=%23lovesyourass",
#    "promoted_content": null,
#    "query": "%23lovesyourass",
#    "tweet_volume": null
#   },
#   {
#    "name": "#BlinksCallOutYG",
#    "url": "http://twitter.com/search?q=%23BlinksCallOutYG",
#    "promoted_content": null,
#    "query": "%23BlinksCallOutYG",
#    "tweet_volume": 161347
#   },
#   {
#    "name": "#smackdownlive",
#    "url": "http://twitter.com/search?q=%23smackdownlive",
#    "promoted_content": null,
#    "query": "%23smackdownlive",
#    "tweet_volume": null
#   },
#   {
#    "name": "#QuitLying",
#    "url": "http://twitter.com/search?q=%23QuitLying",
#    "promoted_content": null,
#    "query": "%23QuitLying",
#    "tweet_volume": null
#   },
#   {
#    "name": "#fridaynight",
#    "url": "http://twitter.com/search?q=%23fridaynight",
#    "promoted_content": null,
#    "query": "%23fridaynight",
#    "tweet_volume": null
#   },
#   {
#    "name": "#fireflyfunhouse",
#    "url": "http://twitter.com/search?q=%23fireflyfunhouse",
#    "promoted_content": null,
#    "query": "%23fireflyfunhouse",
#    "tweet_volume": null
#   },
#   {
#    "name": "#Imisshavingchex",
#    "url": "http://twitter.com/search?q=%23Imisshavingchex",
#    "promoted_content": null,
#    "query": "%23Imisshavingchex",
#    "tweet_volume": null
#   },
#   {
#    "name": "#jeopardyjames",
#    "url": "http://twitter.com/search?q=%23jeopardyjames",
#    "promoted_content": null,
#    "query": "%23jeopardyjames",
#    "tweet_volume": null
#   },
#   {
#    "name": "#askchrisandrian",
#    "url": "http://twitter.com/search?q=%23askchrisandrian",
#    "promoted_content": null,
#    "query": "%23askchrisandrian",
#    "tweet_volume": null
#   },
#   {
#    "name": "#YovanovitchIsAPatriot",
#    "url": "http://twitter.com/search?q=%23YovanovitchIsAPatriot",
#    "promoted_content": null,
#    "query": "%23YovanovitchIsAPatriot",
#    "tweet_volume": 59214
#   },
#   {
#    "name": "#FinancialFollies",
#    "url": "http://twitter.com/search?q=%23FinancialFollies",
#    "promoted_content": null,
#    "query": "%23FinancialFollies",
#    "tweet_volume": null
#   },
#   {
#    "name": "#GOPCorruptionOverCountry",
#    "url": "http://twitter.com/search?q=%23GOPCorruptionOverCountry",
#    "promoted_content": null,
#    "query": "%23GOPCorruptionOverCountry",
#    "tweet_volume": 14158
#   },
#   {
#    "name": "#Txhsfbplayoffs",
#    "url": "http://twitter.com/search?q=%23Txhsfbplayoffs",
#    "promoted_content": null,
#    "query": "%23Txhsfbplayoffs",
#    "tweet_volume": null
#   },
#   {
#    "name": "#SuperMInATL",
#    "url": "http://twitter.com/search?q=%23SuperMInATL",
#    "promoted_content": null,
#    "query": "%23SuperMInATL",
#    "tweet_volume": 20603
#   },
#   {
#    "name": "#RomanceVerifiedFan",
#    "url": "http://twitter.com/search?q=%23RomanceVerifiedFan",
#    "promoted_content": null,
#    "query": "%23RomanceVerifiedFan",
#    "tweet_volume": null
#   },
#   {
#    "name": "#SDOnFox",
#    "url": "http://twitter.com/search?q=%23SDOnFox",
#    "promoted_content": null,
#    "query": "%23SDOnFox",
#    "tweet_volume": null
#   },
#   {
#    "name": "#CapsHabs",
#    "url": "http://twitter.com/search?q=%23CapsHabs",
#    "promoted_content": null,
#    "query": "%23CapsHabs",
#    "tweet_volume": null
#   },
#   {
#    "name": "#FightingForWonho",
#    "url": "http://twitter.com/search?q=%23FightingForWonho",
#    "promoted_content": null,
#    "query": "%23FightingForWonho",
#    "tweet_volume": 247827
#   },
#   {
#    "name": "#UTAatMEM",
#    "url": "http://twitter.com/search?q=%23UTAatMEM",
#    "promoted_content": null,
#    "query": "%23UTAatMEM",
#    "tweet_volume": null
#   }
#  ],
#  "as_of": "2019-11-16T01:53:12Z",
#  "created_at": "2019-11-16T01:49:55Z",
#  "locations": [
#   {
#    "name": "United States",
#    "woeid": 23424977
#   }
#  ]
# }

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %% [markdown]
# Below we create a an empty dict, then insert keys for each location. The values of the keys are sets containing the top 50 trends for the given location.

# %%
trends_set = {}
trends_set['world'] = set([trend_dict['name'] 
                        for trend_dict in world_trends[0]['trends']])

trends_set['us'] = set([trend_dict['name'] 
                     for trend_dict in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend_dict['name'] 
                     for trend_dict in local_trends[0]['trends']])

# %% [markdown]
# By displaying our 'trends_set' dictionary, we can see that our keys for location have been inserted, and they have corresponding values for the trends in the given location.

# %%
trends_set
# Out:
# {'world': {'#AhmetKaya',
#   '#BajarRemuneracionParlamento',
#   '#BlinksCallOutYG',
#   '#ChildrenInNeed',
#   '#CrisisOnInfiniteEarths',
#   '#DearMyIZONE',
#   '#EstoNoHaTerminado',
#   '#ExtortAFilm',
#   '#FightingForWonho',
#   '#FreeCodeFridayContest',
#   '#GHVIP16N',
#   '#GilmarMendesVairCair',
#   '#GolpeDeEstadoEnBoliva',
#   '#MaskSinger',
#   '#MilenioLive',
#   '#MostAnnoyingThingAboutTwitter',
#   '#PlazaDignidad',
#   '#RectaFinal',
#   '#ResignNowTrump',
#   '#Russ',
#   '#SuperM_TENinAtlanta',
#   '#USMNT',
#   '#VoyADejarDeFumar',
#   '#aikatsu',
#   '#boltonfire',
#   '#laluchasigue',
#   '#lovefortheclique',
#   '#lovesyourass',
#   '#oimo',
#   '#propagandalive',
#   '#suspendRudolph',
#   '#ÖrtümeDokunanEliKırarım',
#   '#البراد_هب_ويبيله',
#   '#ايران_تنتفض',
#   '#بوح_اخر_الليل',
#   '#صندوق_الجيش',
#   '#نفسيا_احتاج',
#   '#とんがらし麺と優勝予想ウメブラSP7',
#   '#ウルトラマンタイガ',
#   'Ana Furtado',
#   'Artículo 1',
#   'ESTUDIE VAGA',
#   'Jabbawockeez',
#   'Nicolas Cage',
#   'RESPECT EMILIO',
#   'Tre Jones',
#   'UNIDOS PELO DIEGO',
#   'Voluntad Popular',
#   'Zardes',
#   'メタモン厳選'},
#  'us': {'#BlinksCallOutYG',
#   '#CapsHabs',
#   '#ExtortAFilm',
#   '#FightingForWonho',
#   '#FinancialFollies',
#   '#FreeCodeFridayContest',
#   '#GOPCorruptionOverCountry',
#   '#Imisshavingchex',
#   '#MostAnnoyingThingAboutTwitter',
#   '#QuitLying',
#   '#ResignNowTrump',
#   '#RomanceVerifiedFan',
#   '#SDOnFox',
#   '#SuperMInATL',
#   '#Txhsfbplayoffs',
#   '#USMNT',
#   '#UTAatMEM',
#   '#YovanovitchIsAPatriot',
#   '#askchrisandrian',
#   '#fireflyfunhouse',
#   '#fridaynight',
#   '#jeopardyjames',
#   '#lovesyourass',
#   '#smackdownlive',
#   '#suspendRUDOLPH',
#   'ABDC',
#   'Aaron Long',
#   'Best Harrie',
#   'Da Baby',
#   'David Holmes',
#   'Dest',
#   'Drouin',
#   'Elise',
#   'End 1st',
#   'Isaiah Moss',
#   'Jabbawockeez',
#   'Joey Baker',
#   'John Brooks',
#   'Jordan Morris',
#   'King Corbin',
#   'Mo Wagner',
#   'Nicolas Cage',
#   'Rick Santorum',
#   'Samsonov',
#   'Shorty G',
#   'Tedra Cobb',
#   'Tre Jones',
#   'Universal Championship',
#   'Yelich',
#   'Zardes'},
#  'san diego': {'#BlinksCallOutYG',
#   '#ExtortAFilm',
#   '#FightingForWonho',
#   '#FinancialFollies',
#   '#FreeCodeFridayContest',
#   '#GOPCorruptionOverCountry',
#   '#Imisshavingchex',
#   '#ImpeachingHearings',
#   '#Jackets50',
#   '#MostAnnoyingThingAboutTwitter',
#   '#QuitLying',
#   '#ResignNowTrump',
#   '#RomanceVerifiedFan',
#   '#SDOnFox',
#   '#SuperMInATL',
#   '#Txhsfbplayoffs',
#   '#USMNT',
#   '#YovanovitchIsAPatriot',
#   '#askchrisandrian',
#   '#fireflyfunhouse',
#   '#fridaynight',
#   '#jeopardyjames',
#   '#lovesyourass',
#   '#themandolorian',
#   'ABDC',
#   'Aaron Long',
#   'Da Baby',
#   'David Holmes',
#   'Dest',
#   'Drouin',
#   'Elise',
#   'Empire Strikes Back',
#   'End 1st',
#   'Jabbawockeez',
#   'Joey Baker',
#   'John Brooks',
#   'Jordan Morris',
#   'Mason',
#   'Myles',
#   'Nicolas Cage',
#   'Rick Santorum',
#   'Rudolph',
#   'Samsonov',
#   'Shorty G',
#   'Stone',
#   'Tedra Cobb',
#   'Tre Jones',
#   'Universal Championship',
#   'Yelich',
#   'Zardes'}}

# %% [markdown]
# The `.join()` method in Python is a string method that returns a string in which the elements of sequence have been joined by a str separator.
#
# Syntax: `string_name.join(iterable)` where string_name is the name of string in which joined elements of iterable (e.g. List, Tuple, String, Dictionary and Set) will be stored. The returned value is a string concatenated with the elements of iterable.

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((', '.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #USMNT, #とんがらし麺と優勝予想ウメブラSP7, #ResignNowTrump, #CrisisOnInfiniteEarths, メタモン厳選, #MilenioLive, UNIDOS PELO DIEGO, #AhmetKaya, #ExtortAFilm, #نفسيا_احتاج, #البراد_هب_ويبيله, #BlinksCallOutYG, #MaskSinger, Artículo 1, #boltonfire, #laluchasigue, Zardes, Tre Jones, #propagandalive, ESTUDIE VAGA, #VoyADejarDeFumar, #بوح_اخر_الليل, #MostAnnoyingThingAboutTwitter, #oimo, #suspendRudolph, #GHVIP16N, #ايران_تنتفض, #lovefortheclique, #Russ, RESPECT EMILIO, #ÖrtümeDokunanEliKırarım, #GolpeDeEstadoEnBoliva, #GilmarMendesVairCair, #RectaFinal, #aikatsu, Nicolas Cage, #ウルトラマンタイガ, #BajarRemuneracionParlamento, #lovesyourass, #FreeCodeFridayContest, #FightingForWonho, Jabbawockeez, #EstoNoHaTerminado, #صندوق_الجيش, #ChildrenInNeed, #SuperM_TENinAtlanta, #PlazaDignidad, Ana Furtado, Voluntad Popular, #DearMyIZONE
# ('----------', 'us')
# Samsonov, Best Harrie, Rick Santorum, #USMNT, #ResignNowTrump, Universal Championship, Aaron Long, Joey Baker, #suspendRUDOLPH, Shorty G, #ExtortAFilm, #CapsHabs, #FinancialFollies, #BlinksCallOutYG, End 1st, Drouin, #Txhsfbplayoffs, David Holmes, Zardes, Tre Jones, Elise, #MostAnnoyingThingAboutTwitter, #Imisshavingchex, #UTAatMEM, ABDC, Isaiah Moss, #jeopardyjames, #RomanceVerifiedFan, Tedra Cobb, Yelich, #SDOnFox, Nicolas Cage, #fridaynight, #smackdownlive, #QuitLying, #lovesyourass, #FreeCodeFridayContest, #FightingForWonho, John Brooks, #SuperMInATL, Jabbawockeez, Jordan Morris, King Corbin, #fireflyfunhouse, #askchrisandrian, Da Baby, Dest, #GOPCorruptionOverCountry, Mo Wagner, #YovanovitchIsAPatriot
# ('----------', 'san diego')
# Samsonov, #ImpeachingHearings, Rick Santorum, Myles, Da Baby, #USMNT, #ResignNowTrump, Universal Championship, Aaron Long, Mason, #Jackets50, Shorty G, #ExtortAFilm, #FinancialFollies, Empire Strikes Back, #BlinksCallOutYG, End 1st, Drouin, #Txhsfbplayoffs, David Holmes, Zardes, Tre Jones, Elise, #MostAnnoyingThingAboutTwitter, #Imisshavingchex, ABDC, #RomanceVerifiedFan, #jeopardyjames, Tedra Cobb, Yelich, Rudolph, #SDOnFox, Nicolas Cage, #fridaynight, #QuitLying, #lovesyourass, #FreeCodeFridayContest, John Brooks, #SuperMInATL, Jabbawockeez, Jordan Morris, #fireflyfunhouse, #askchrisandrian, #GOPCorruptionOverCountry, Joey Baker, Dest, #FightingForWonho, #themandolorian, #YovanovitchIsAPatriot, Stone

# %% [markdown]
# The Python set `.intersection()` method returns a set that contains items that coexist in all argued sets.
#
# Syntax: set.intersection(set1, set2 ... etc.)
#
# Below we use the intersection method to see what trends coexist in the world and the US, as well as trends that coexist in the US and San Diego. As can be seen, there are more trends in common between the US and San Diego, as would be expected.

# %%
print(( '='*10,'intersection of world and us trends'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego trends'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us trends')
# {'#ExtortAFilm', 'Nicolas Cage', '#MostAnnoyingThingAboutTwitter', '#lovesyourass', '#USMNT', '#FreeCodeFridayContest', '#FightingForWonho', '#ResignNowTrump', 'Jabbawockeez', '#BlinksCallOutYG', 'Zardes', 'Tre Jones'}
# ('==========', 'intersection of us and san-diego trends')
# {'Samsonov', 'Da Baby', 'Rick Santorum', '#USMNT', '#ResignNowTrump', 'Universal Championship', 'Aaron Long', 'Shorty G', '#ExtortAFilm', 'Dest', '#FinancialFollies', 'End 1st', 'Drouin', '#Txhsfbplayoffs', 'David Holmes', 'Zardes', 'Tre Jones', 'Elise', '#MostAnnoyingThingAboutTwitter', '#Imisshavingchex', 'ABDC', '#RomanceVerifiedFan', '#jeopardyjames', 'Tedra Cobb', 'Yelich', '#SDOnFox', 'Nicolas Cage', '#fridaynight', '#QuitLying', '#lovesyourass', '#FreeCodeFridayContest', '#FightingForWonho', 'John Brooks', '#SuperMInATL', 'Jabbawockeez', 'Jordan Morris', '#fireflyfunhouse', '#askchrisandrian', 'Joey Baker', '#BlinksCallOutYG', '#GOPCorruptionOverCountry', '#YovanovitchIsAPatriot'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter
#
# The Twitter API object `.search.tweets(q, count)` method is used to search twitter for a specified hashtag, and return the tweets (along with lots of other information, e.g. metadata) as result in JSON format. Arguments 'q' is the hashtag and 'count' is the number of tweets you want returned.

# %%
q = '#tea' 
num = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=num)
print(search_results.keys())

statuses = search_results['statuses']
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
print(len(statuses))
#print(statuses)
print(type(statuses))
# Out:
# 75
# <class 'list'>

# %%
print(json.dumps(statuses, indent=1))
# Out:
# [
#  {
#   "created_at": "Sat Nov 16 08:25:33 +0000 2019",
#   "id": 1195618899917787137,
#   "id_str": "1195618899917787137",
#   "text": "It\u2019s funny how you\u2019ll ignore me for hours, butttt if it\u2019s someone you want to fuck or interested in you\u2019re still li\u2026 https://t.co/62b0FaTsrl",
#   "truncated": true,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/62b0FaTsrl",
#      "expanded_url": "https://twitter.com/i/web/status/1195618899917787137",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1184495801495703554,
#    "id_str": "1184495801495703554",
#    "name": "Relatable Queen",
#    "screen_name": "RelatableQuee",
#    "location": "Atlanta, GA",
#    "description": "Sarcastic Socialite. Relatable Queen. Podcaster. Be a slut, have fun, get tested ! #relatablequeenpodcast",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 19,
#    "friends_count": 64,
#    "listed_count": 0,
#    "created_at": "Wed Oct 16 15:46:33 +0000 2019",
#    "favourites_count": 46,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 62,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1184500138905079817/6q5QR_dr_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1184500138905079817/6q5QR_dr_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1184495801495703554/1571241785",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:25:13 +0000 2019",
#   "id": 1195618812999151617,
#   "id_str": "1195618812999151617",
#   "text": "Fraser takes making a fish tea very seriously... And literally.\n\n#toddler #cooking #fish #tea #fishtea #glasgow\u2026 https://t.co/8LOexe2Gz2",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "toddler",
#      "indices": [
#       65,
#       73
#      ]
#     },
#     {
#      "text": "cooking",
#      "indices": [
#       74,
#       82
#      ]
#     },
#     {
#      "text": "fish",
#      "indices": [
#       83,
#       88
#      ]
#     },
#     {
#      "text": "tea",
#      "indices": [
#       89,
#       93
#      ]
#     },
#     {
#      "text": "fishtea",
#      "indices": [
#       94,
#       102
#      ]
#     },
#     {
#      "text": "glasgow",
#      "indices": [
#       103,
#       111
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [
#     {
#      "url": "https://t.co/8LOexe2Gz2",
#      "expanded_url": "https://twitter.com/i/web/status/1195618812999151617",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       113,
#       136
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 68789548,
#    "id_str": "68789548",
#    "name": "Rob Nelson",
#    "screen_name": "rabthecrab",
#    "location": "Glasgow",
#    "description": "Creative at @redblugraphics, likes snow and beers, dislikes celery.",
#    "url": "https://t.co/nlX3wsD209",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/nlX3wsD209",
#        "expanded_url": "http://www.redblugraphics.co.uk",
#        "display_url": "redblugraphics.co.uk",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 317,
#    "friends_count": 1146,
#    "listed_count": 14,
#    "created_at": "Tue Aug 25 19:51:17 +0000 2009",
#    "favourites_count": 300,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 3994,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "022330",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme15/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme15/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1174973460138774528/Wo5UZhYr_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1174973460138774528/Wo5UZhYr_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/68789548/1472250956",
#    "profile_link_color": "0084B4",
#    "profile_sidebar_border_color": "A8C7F7",
#    "profile_sidebar_fill_color": "C0DFEC",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:24:26 +0000 2019",
#   "id": 1195618616739123200,
#   "id_str": "1195618616739123200",
#   "text": "@costacoffee time #MummyAndSon #Breakfast #Tea #SausageBap #Family #TimeTogether #ActuallyHisIdea ! https://t.co/Jg7qEPFyOF",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MummyAndSon",
#      "indices": [
#       18,
#       30
#      ]
#     },
#     {
#      "text": "Breakfast",
#      "indices": [
#       31,
#       41
#      ]
#     },
#     {
#      "text": "Tea",
#      "indices": [
#       42,
#       46
#      ]
#     },
#     {
#      "text": "SausageBap",
#      "indices": [
#       47,
#       58
#      ]
#     },
#     {
#      "text": "Family",
#      "indices": [
#       59,
#       66
#      ]
#     },
#     {
#      "text": "TimeTogether",
#      "indices": [
#       67,
#       80
#      ]
#     },
#     {
#      "text": "ActuallyHisIdea",
#      "indices": [
#       81,
#       97
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "CostaCoffee",
#      "name": "Costa Coffee",
#      "id": 16696296,
#      "id_str": "16696296",
#      "indices": [
#       0,
#       12
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/Jg7qEPFyOF",
#      "expanded_url": "https://www.instagram.com/p/B462QiVlNNFcVCQxfkIeXxQevyQOCIS1w1Y7E80/?igshid=11ecvw85i3bro",
#      "display_url": "instagram.com/p/B462QiVlNNFc\u2026",
#      "indices": [
#       100,
#       123
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": 16696296,
#   "in_reply_to_user_id_str": "16696296",
#   "in_reply_to_screen_name": "CostaCoffee",
#   "user": {
#    "id": 36749180,
#    "id_str": "36749180",
#    "name": "Rachel Simpson",
#    "screen_name": "RachelSimpson82",
#    "location": "UK",
#    "description": "The Official Rachel Simpson Twitter Page",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 207,
#    "friends_count": 1057,
#    "listed_count": 2,
#    "created_at": "Thu Apr 30 19:33:07 +0000 2009",
#    "favourites_count": 432,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 8941,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "131516",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1151435161642446849/Z2Eo7ANy_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1151435161642446849/Z2Eo7ANy_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/36749180/1562438775",
#    "profile_link_color": "009999",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:23:47 +0000 2019",
#   "id": 1195618453907857408,
#   "id_str": "1195618453907857408",
#   "text": "Winter days and Tea!!\nAlways a better love story!!\n#Tea #Love https://t.co/xcxB7wudqS",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "Tea",
#      "indices": [
#       51,
#       55
#      ]
#     },
#     {
#      "text": "Love",
#      "indices": [
#       56,
#       61
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1195618438082748416,
#      "id_str": "1195618438082748416",
#      "indices": [
#       62,
#       85
#      ],
#      "media_url": "http://pbs.twimg.com/media/EJewooDUYAA5xuI.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/EJewooDUYAA5xuI.jpg",
#      "url": "https://t.co/xcxB7wudqS",
#      "display_url": "pic.twitter.com/xcxB7wudqS",
#      "expanded_url": "https://twitter.com/lfc_ashish/status/1195618453907857408/photo/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 722,
#        "h": 1200,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1233,
#        "h": 2048,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 409,
#        "h": 680,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1195618438082748416,
#      "id_str": "1195618438082748416",
#      "indices": [
#       62,
#       85
#      ],
#      "media_url": "http://pbs.twimg.com/media/EJewooDUYAA5xuI.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/EJewooDUYAA5xuI.jpg",
#      "url": "https://t.co/xcxB7wudqS",
#      "display_url": "pic.twitter.com/xcxB7wudqS",
#      "expanded_url": "https://twitter.com/lfc_ashish/status/1195618453907857408/photo/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 722,
#        "h": 1200,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1233,
#        "h": 2048,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 409,
#        "h": 680,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 300806979,
#    "id_str": "300806979",
#    "name": "Ashish Regmi",
#    "screen_name": "lfc_ashish",
#    "location": "Himalayas",
#    "description": "I used to be a dreamer. Now I am a seeker.\n#Nepali #SelfEmployed #MBA #Student\r#Football #Music\n#LiverpoolFCFanatic\n#YNWA  #JFT96.",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 770,
#    "friends_count": 1176,
#    "listed_count": 7,
#    "created_at": "Wed May 18 11:50:06 +0000 2011",
#    "favourites_count": 5043,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 2029,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "EBC1D0",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/843645075309568000/-UQk0G9i_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/843645075309568000/-UQk0G9i_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/300806979/1565925128",
#    "profile_link_color": "DD2E44",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 1,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:20:57 +0000 2019",
#   "id": 1195617740209479680,
#   "id_str": "1195617740209479680",
#   "text": "RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc\u2026",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "dorset_tea",
#      "name": "Dorset Tea",
#      "id": 87220808,
#      "id_str": "87220808",
#      "indices": [
#       3,
#       14
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 21768742,
#    "id_str": "21768742",
#    "name": "Lucy Bonson",
#    "screen_name": "Lucy_lou79",
#    "location": "United Kingdom",
#    "description": "I'm a Disney Parks loving lady with a lovely son\ud83d\udc96 a Blackburn Rovers supporter.....\ud83d\udc96\ud83d\udc96always looking for new mates \ud83d\udc96",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 391,
#    "friends_count": 3082,
#    "listed_count": 6,
#    "created_at": "Tue Feb 24 16:34:27 +0000 2009",
#    "favourites_count": 1814,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 2256,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1087344925296025606/0CS9XOoJ_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1087344925296025606/0CS9XOoJ_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/21768742/1552239682",
#    "profile_link_color": "0084B4",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Fri Nov 15 08:30:26 +0000 2019",
#    "id": 1195257740983177216,
#    "id_str": "1195257740983177216",
#    "text": "Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For yo\u2026 https://t.co/jX0cFrnqOo",
#    "truncated": true,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/jX0cFrnqOo",
#       "expanded_url": "https://twitter.com/i/web/status/1195257740983177216",
#       "display_url": "twitter.com/i/web/status/1\u2026",
#       "indices": [
#        117,
#        140
#       ]
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 87220808,
#     "id_str": "87220808",
#     "name": "Dorset Tea",
#     "screen_name": "dorset_tea",
#     "location": "Instagram: DorsetTeaUK",
#     "description": "Tea that tastes as good as the sunshine makes you feel\ud83c\udf1e all available at https://t.co/gy8yYMWlmB",
#     "url": "https://t.co/gy8yYMWlmB",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/gy8yYMWlmB",
#         "expanded_url": "http://www.dorsettea.co.uk",
#         "display_url": "dorsettea.co.uk",
#         "indices": [
#          0,
#          23
#         ]
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "https://t.co/gy8yYMWlmB",
#         "expanded_url": "http://www.dorsettea.co.uk",
#         "display_url": "dorsettea.co.uk",
#         "indices": [
#          73,
#          96
#         ]
#        }
#       ]
#      }
#     },
#     "protected": false,
#     "followers_count": 17761,
#     "friends_count": 4930,
#     "listed_count": 151,
#     "created_at": "Tue Nov 03 16:02:00 +0000 2009",
#     "favourites_count": 9865,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "verified": false,
#     "statuses_count": 9398,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "98DAEA",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1083284547385638912/4Mz-gFMj_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1083284547385638912/4Mz-gFMj_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/87220808/1564579565",
#     "profile_link_color": "98DAEA",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "000000",
#     "profile_text_color": "000000",
#     "profile_use_background_image": true,
#     "has_extended_profile": false,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 370,
#    "favorite_count": 406,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "en"
#   },
#   "is_quote_status": false,
#   "retweet_count": 370,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:20:18 +0000 2019",
#   "id": 1195617578967879680,
#   "id_str": "1195617578967879680",
#   "text": "RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc\u2026",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "dorset_tea",
#      "name": "Dorset Tea",
#      "id": 87220808,
#      "id_str": "87220808",
#      "indices": [
#       3,
#       14
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 37761373,
#    "id_str": "37761373",
#    "name": "clare munden",
#    "screen_name": "claremunden",
#    "location": "southampton",
#    "description": "30 flirty and thriving +1",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 876,
#    "friends_count": 4966,
#    "listed_count": 81,
#    "created_at": "Mon May 04 21:12:15 +0000 2009",
#    "favourites_count": 11449,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 16850,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/748072208828895232/NCGjz-yO_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/748072208828895232/NCGjz-yO_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/37761373/1467189289",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Fri Nov 15 08:30:26 +0000 2019",
#    "id": 1195257740983177216,
#    "id_str": "1195257740983177216",
#    "text": "Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For yo\u2026 https://t.co/jX0cFrnqOo",
#    "truncated": true,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/jX0cFrnqOo",
#       "expanded_url": "https://twitter.com/i/web/status/1195257740983177216",
#       "display_url": "twitter.com/i/web/status/1\u2026",
#       "indices": [
#        117,
#        140
#       ]
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 87220808,
#     "id_str": "87220808",
#     "name": "Dorset Tea",
#     "screen_name": "dorset_tea",
#     "location": "Instagram: DorsetTeaUK",
#     "description": "Tea that tastes as good as the sunshine makes you feel\ud83c\udf1e all available at https://t.co/gy8yYMWlmB",
#     "url": "https://t.co/gy8yYMWlmB",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/gy8yYMWlmB",
#         "expanded_url": "http://www.dorsettea.co.uk",
#         "display_url": "dorsettea.co.uk",
#         "indices": [
#          0,
#          23
#         ]
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "https://t.co/gy8yYMWlmB",
#         "expanded_url": "http://www.dorsettea.co.uk",
#         "display_url": "dorsettea.co.uk",
#         "indices": [
#          73,
#          96
#         ]
#        }
#       ]
#      }
#     },
#     "protected": false,
#     "followers_count": 17761,
#     "friends_count": 4930,
#     "listed_count": 151,
#     "created_at": "Tue Nov 03 16:02:00 +0000 2009",
#     "favourites_count": 9865,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "verified": false,
#     "statuses_count": 9398,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "98DAEA",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1083284547385638912/4Mz-gFMj_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1083284547385638912/4Mz-gFMj_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/87220808/1564579565",
#     "profile_link_color": "98DAEA",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "000000",
#     "profile_text_color": "000000",
#     "profile_use_background_image": true,
#     "has_extended_profile": false,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 370,
#    "favorite_count": 406,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "en"
#   },
#   "is_quote_status": false,
#   "retweet_count": 370,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:19:18 +0000 2019",
#   "id": 1195617325061476352,
#   "id_str": "1195617325061476352",
#   "text": "RT @Grupo_Aitana: A menudo los ni\u00f1os con #TEA son detectados por la presencia de problemas de conducta #aitana2019 https://t.co/MSzYVKAPAJ",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "TEA",
#      "indices": [
#       41,
#       45
#      ]
#     },
#     {
#      "text": "aitana2019",
#      "indices": [
#       103,
#       114
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "Grupo_Aitana",
#      "name": "Grupo Aitana",
#      "id": 558515204,
#      "id_str": "558515204",
#      "indices": [
#       3,
#       16
#      ]
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "id": 1194951939542437888,
#      "id_str": "1194951939542437888",
#      "indices": [
#       115,
#       138
#      ],
#      "media_url": "http://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#      "url": "https://t.co/MSzYVKAPAJ",
#      "display_url": "pic.twitter.com/MSzYVKAPAJ",
#      "expanded_url": "https://twitter.com/Grupo_Aitana/status/1194951944986615810/photo/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1024,
#        "h": 768,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1024,
#        "h": 768,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 510,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 1194951944986615810,
#      "source_status_id_str": "1194951944986615810",
#      "source_user_id": 558515204,
#      "source_user_id_str": "558515204"
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1194951939542437888,
#      "id_str": "1194951939542437888",
#      "indices": [
#       115,
#       138
#      ],
#      "media_url": "http://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#      "url": "https://t.co/MSzYVKAPAJ",
#      "display_url": "pic.twitter.com/MSzYVKAPAJ",
#      "expanded_url": "https://twitter.com/Grupo_Aitana/status/1194951944986615810/photo/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1024,
#        "h": 768,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1024,
#        "h": 768,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 510,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 1194951944986615810,
#      "source_status_id_str": "1194951944986615810",
#      "source_user_id": 558515204,
#      "source_user_id_str": "558515204"
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "es",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 735816990288404480,
#    "id_str": "735816990288404480",
#    "name": "Psico y Neuro ibiza",
#    "screen_name": "psico_y",
#    "location": "Eivissa, Espa\u00f1a",
#    "description": "Alicia Ribas Mar\u00ed\n Col. B-02552\n Psic\u00f3loga y Neuropsic\u00f3loga en Ibiza",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 182,
#    "friends_count": 323,
#    "listed_count": 3,
#    "created_at": "Thu May 26 12:56:56 +0000 2016",
#    "favourites_count": 40,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 785,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/737208221706883072/Wcswldw6_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/737208221706883072/Wcswldw6_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/735816990288404480/1536318055",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Thu Nov 14 12:15:19 +0000 2019",
#    "id": 1194951944986615810,
#    "id_str": "1194951944986615810",
#    "text": "A menudo los ni\u00f1os con #TEA son detectados por la presencia de problemas de conducta #aitana2019 https://t.co/MSzYVKAPAJ",
#    "truncated": false,
#    "entities": {
#     "hashtags": [
#      {
#       "text": "TEA",
#       "indices": [
#        23,
#        27
#       ]
#      },
#      {
#       "text": "aitana2019",
#       "indices": [
#        85,
#        96
#       ]
#      }
#     ],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [],
#     "media": [
#      {
#       "id": 1194951939542437888,
#       "id_str": "1194951939542437888",
#       "indices": [
#        97,
#        120
#       ],
#       "media_url": "http://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#       "media_url_https": "https://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#       "url": "https://t.co/MSzYVKAPAJ",
#       "display_url": "pic.twitter.com/MSzYVKAPAJ",
#       "expanded_url": "https://twitter.com/Grupo_Aitana/status/1194951944986615810/photo/1",
#       "type": "photo",
#       "sizes": {
#        "thumb": {
#         "w": 150,
#         "h": 150,
#         "resize": "crop"
#        },
#        "medium": {
#         "w": 1024,
#         "h": 768,
#         "resize": "fit"
#        },
#        "large": {
#         "w": 1024,
#         "h": 768,
#         "resize": "fit"
#        },
#        "small": {
#         "w": 680,
#         "h": 510,
#         "resize": "fit"
#        }
#       }
#      }
#     ]
#    },
#    "extended_entities": {
#     "media": [
#      {
#       "id": 1194951939542437888,
#       "id_str": "1194951939542437888",
#       "indices": [
#        97,
#        120
#       ],
#       "media_url": "http://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#       "media_url_https": "https://pbs.twimg.com/media/EJVSdTgXUAAH_1J.jpg",
#       "url": "https://t.co/MSzYVKAPAJ",
#       "display_url": "pic.twitter.com/MSzYVKAPAJ",
#       "expanded_url": "https://twitter.com/Grupo_Aitana/status/1194951944986615810/photo/1",
#       "type": "photo",
#       "sizes": {
#        "thumb": {
#         "w": 150,
#         "h": 150,
#         "resize": "crop"
#        },
#        "medium": {
#         "w": 1024,
#         "h": 768,
#         "resize": "fit"
#        },
#        "large": {
#         "w": 1024,
#         "h": 768,
#         "resize": "fit"
#        },
#        "small": {
#         "w": 680,
#         "h": 510,
#         "resize": "fit"
#        }
#       }
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "es",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 558515204,
#     "id_str": "558515204",
#     "name": "Grupo Aitana",
#     "screen_name": "Grupo_Aitana",
#     "location": "Oviedo, Espa\u00f1a",
#     "description": "5th International Congress of Clinical and Health Psychology on Children and Adolescents (14 - 16 November 2019)",
#     "url": "https://t.co/ynQEbqMw5X",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/ynQEbqMw5X",
#         "expanded_url": "http://www.aitanacongress.com/2019",
#         "display_url": "aitanacongress.com/2019",
#         "indices": [
#          0,
#          23
#         ]
#        }
#       ]
#      },
#      "description": {
#       "urls": []
#      }
#     },
#     "protected": false,
#     "followers_count": 1064,
#     "friends_count": 778,
#     "listed_count": 19,
#     "created_at": "Fri Apr 20 10:35:42 +0000 2012",
#     "favourites_count": 847,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "verified": false,
#     "statuses_count": 1328,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "000000",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1064845776235433984/vrlJqoyp_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1064845776235433984/vrlJqoyp_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/558515204/1573820128",
#     "profile_link_color": "89C9FA",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "000000",
#     "profile_text_color": "000000",
#     "profile_use_background_image": false,
#     "has_extended_profile": false,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 2,
#    "favorite_count": 7,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "es"
#   },
#   "is_quote_status": false,
#   "retweet_count": 2,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "es"
#  },
#  {
#   "created_at": "Sat Nov 16 08:18:29 +0000 2019",
#   "id": 1195617118869434368,
#   "id_str": "1195617118869434368",
#   "text": "RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc\u2026",
#   "truncated": false,
#   "entities": {
#    "hashtags": [],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "dorset_tea",
#      "name": "Dorset Tea",
#      "id": 87220808,
#      "id_str": "87220808",
#      "indices": [
#       3,
#       14
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 2279218303,
#    "id_str": "2279218303",
#    "name": "Diane Radford",
#    "screen_name": "dianestar17",
#    "location": "Kent, UK",
#    "description": "Wife, Mummy and new Blogger. https://t.co/OLBXOcpjXv",
#    "url": "https://t.co/zXJzmws9Va",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/zXJzmws9Va",
#        "expanded_url": "http://www.mumandmatilda.wordpress.com",
#        "display_url": "mumandmatilda.wordpress.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": [
#       {
#        "url": "https://t.co/OLBXOcpjXv",
#        "expanded_url": "http://mumandmatilda.wordpress.com",
#        "display_url": "mumandmatilda.wordpress.com",
#        "indices": [
#         29,
#         52
#        ]
#       }
#      ]
#     }
#    },
#    "protected": false,
#    "followers_count": 1016,
#    "friends_count": 4547,
#    "listed_count": 53,
#    "created_at": "Mon Jan 06 15:13:06 +0000 2014",
#    "favourites_count": 29281,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 57245,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C1DEAD",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1192752156027297792/rHgvjBYA_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1192752156027297792/rHgvjBYA_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2279218303/1569603608",
#    "profile_link_color": "038543",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Fri Nov 15 08:30:26 +0000 2019",
#    "id": 1195257740983177216,
#    "id_str": "1195257740983177216",
#    "text": "Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For yo\u2026 https://t.co/jX0cFrnqOo",
#    "truncated": true,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/jX0cFrnqOo",
#       "expanded_url": "https://twitter.com/i/web/status/1195257740983177216",
#       "display_url": "twitter.com/i/web/status/1\u2026",
#       "indices": [
#        117,
#        140
#       ]
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "en",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"https://www.hootsuite.com\" rel=\"nofollow\">Hootsuite Inc.</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 87220808,
#     "id_str": "87220808",
#     "name": "Dorset Tea",
#     "screen_name": "dorset_tea",
#     "location": "Instagram: DorsetTeaUK",
#     "description": "Tea that tastes as good as the sunshine makes you feel\ud83c\udf1e all available at https://t.co/gy8yYMWlmB",
#     "url": "https://t.co/gy8yYMWlmB",
#     "entities": {
#      "url": {
#       "urls": [
#        {
#         "url": "https://t.co/gy8yYMWlmB",
#         "expanded_url": "http://www.dorsettea.co.uk",
#         "display_url": "dorsettea.co.uk",
#         "indices": [
#          0,
#          23
#         ]
#        }
#       ]
#      },
#      "description": {
#       "urls": [
#        {
#         "url": "https://t.co/gy8yYMWlmB",
#         "expanded_url": "http://www.dorsettea.co.uk",
#         "display_url": "dorsettea.co.uk",
#         "indices": [
#          73,
#          96
#         ]
#        }
#       ]
#      }
#     },
#     "protected": false,
#     "followers_count": 17761,
#     "friends_count": 4930,
#     "listed_count": 151,
#     "created_at": "Tue Nov 03 16:02:00 +0000 2009",
#     "favourites_count": 9865,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": true,
#     "verified": false,
#     "statuses_count": 9398,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "98DAEA",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1083284547385638912/4Mz-gFMj_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1083284547385638912/4Mz-gFMj_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/87220808/1564579565",
#     "profile_link_color": "98DAEA",
#     "profile_sidebar_border_color": "000000",
#     "profile_sidebar_fill_color": "000000",
#     "profile_text_color": "000000",
#     "profile_use_background_image": true,
#     "has_extended_profile": false,
#     "default_profile": false,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 370,
#    "favorite_count": 406,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "en"
#   },
#   "is_quote_status": false,
#   "retweet_count": 370,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 08:18:14 +0000 2019",
#   "id": 1195617058119147520,
#   "id_str": "1195617058119147520",
#   "text": "RT @CerebrodeMaria: Os voy a contar algo porque me apetece.\nComo sab\u00e9is algunos todos los d\u00edas mi hijo #TEA y yo vamos y venimos del cole e\u2026",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "TEA",
#      "indices": [
#       103,
#       107
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "CerebrodeMaria",
#      "name": "Maria",
#      "id": 1101632806546034689,
#      "id_str": "1101632806546034689",
#      "indices": [
#       3,
#       18
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "es",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 1729271748,
#    "id_str": "1729271748",
#    "name": "Aito Carro",
#    "screen_name": "aitocarro",
#    "location": "Un no s\u00e9 qu\u00e9 me pasa...",
#    "description": "",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 110,
#    "friends_count": 229,
#    "listed_count": 4,
#    "created_at": "Wed Sep 04 16:51:59 +0000 2013",
#    "favourites_count": 5269,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 2618,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "C0DEED",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/378800000715528047/8e74d2537d1a2edc38148241ec35f8e9_normal.jpeg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/378800000715528047/8e74d2537d1a2edc38148241ec35f8e9_normal.jpeg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/1729271748/1383997577",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Fri Nov 15 13:58:17 +0000 2019",
#    "id": 1195340247313395713,
#    "id_str": "1195340247313395713",
#    "text": "Os voy a contar algo porque me apetece.\nComo sab\u00e9is algunos todos los d\u00edas mi hijo #TEA y yo vamos y venimos del co\u2026 https://t.co/PVGD41BMry",
#    "truncated": true,
#    "entities": {
#     "hashtags": [
#      {
#       "text": "TEA",
#       "indices": [
#        83,
#        87
#       ]
# ...
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/831680224970600448/xyF09pVW_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/244222211/1519141358",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Sat Nov 16 00:53:29 +0000 2019",
#    "id": 1195505132441616384,
#    "id_str": "1195505132441616384",
#    "text": "\ud83d\udc99\ud83d\udc99Para los q esten en las marchas y hacen q el q baila pasa. respeten si llevan pa\u00f1uelo azul ahi viaja una persona\u2026 https://t.co/JvcdQfX2K1",
#    "truncated": true,
#    "entities": {
#     "hashtags": [],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/JvcdQfX2K1",
#       "expanded_url": "https://twitter.com/i/web/status/1195505132441616384",
#       "display_url": "twitter.com/i/web/status/1\u2026",
#       "indices": [
#        116,
#        139
#       ]
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "es",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 352726281,
#     "id_str": "352726281",
#     "name": "PurpurAzul",
#     "screen_name": "pereira_marce",
#     "location": "",
#     "description": "Amo a mi hija, lucho d\u00eda a d\u00eda por su inclusi\u00f3n a esta sociedad. Cristiana, agradecida de Dios d\u00eda a d\u00eda, 100% social, Dem\u00f3crata.",
#     "url": null,
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "protected": false,
#     "followers_count": 305,
#     "friends_count": 896,
#     "listed_count": 1,
#     "created_at": "Thu Aug 11 00:52:08 +0000 2011",
#     "favourites_count": 2749,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "verified": false,
#     "statuses_count": 3056,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "C0DEED",
#     "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1067099414475522048/su-zqz6X_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1067099414475522048/su-zqz6X_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/352726281/1543251301",
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "has_extended_profile": false,
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 40,
#    "favorite_count": 33,
#    "favorited": false,
#    "retweeted": false,
#    "lang": "es"
#   },
#   "is_quote_status": false,
#   "retweet_count": 40,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "es"
#  },
#  {
#   "created_at": "Sat Nov 16 06:05:20 +0000 2019",
#   "id": 1195583611153649665,
#   "id_str": "1195583611153649665",
#   "text": "@MomWifeHustler What is CBD? #CBD free education in under 2 mins  https://t.co/mRDptXh9qk \nCBD free education &amp; pur\u2026 https://t.co/P1n1AYWJum",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "CBD",
#      "indices": [
#       29,
#       33
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "MomWifeHustler",
#      "name": "\ud83e\udd8d\ud83e\uddd8\ud83c\udffd\u200d\u2640\ufe0f",
#      "id": 250388242,
#      "id_str": "250388242",
#      "indices": [
#       0,
#       15
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/mRDptXh9qk",
#      "expanded_url": "https://youtu.be/2GohQzekxHU",
#      "display_url": "youtu.be/2GohQzekxHU",
#      "indices": [
#       66,
#       89
#      ]
#     },
#     {
#      "url": "https://t.co/P1n1AYWJum",
#      "expanded_url": "https://twitter.com/i/web/status/1195583611153649665",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       121,
#       144
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#   "in_reply_to_status_id": 1195495138014957573,
#   "in_reply_to_status_id_str": "1195495138014957573",
#   "in_reply_to_user_id": 250388242,
#   "in_reply_to_user_id_str": "250388242",
#   "in_reply_to_screen_name": "MomWifeHustler",
#   "user": {
#    "id": 33939530,
#    "id_str": "33939530",
#    "name": "Okang McBride",
#    "screen_name": "_mco",
#    "location": "USA",
#    "description": "I help people become Successful by Paying Themselves First through Personal Development, Leadership & Entrepreneurship.",
#    "url": "https://t.co/XcTAjYoRya",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/XcTAjYoRya",
#        "expanded_url": "http://oxzgen.com/L372602",
#        "display_url": "oxzgen.com/L372602",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 755,
#    "friends_count": 811,
#    "listed_count": 10,
#    "created_at": "Tue Apr 21 15:36:55 +0000 2009",
#    "favourites_count": 13439,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 27521,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme18/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme18/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1098588890569625601/7KPc8G6f_normal.png",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1098588890569625601/7KPc8G6f_normal.png",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/33939530/1571932724",
#    "profile_link_color": "1B95E0",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 0,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  {
#   "created_at": "Sat Nov 16 06:04:23 +0000 2019",
#   "id": 1195583371599990784,
#   "id_str": "1195583371599990784",
#   "text": "RT @DesiKulhad: #\u091a\u093e\u092f #\u091a\u0939\u093e #\u0936\u093e\u092f\u0930\u0940 #teacafe #tea #Tea #teaflavour #flavoroflove #flavouredtea #flavour #flavourtea #coffeetime #coffee #coffe\u2026",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "\u091a\u093e\u092f",
#      "indices": [
#       16,
#       20
#      ]
#     },
#     {
#      "text": "\u091a\u0939\u093e",
#      "indices": [
#       21,
#       25
#      ]
#     },
#     {
#      "text": "\u0936\u093e\u092f\u0930\u0940",
#      "indices": [
#       26,
#       32
#      ]
#     },
#     {
#      "text": "teacafe",
#      "indices": [
#       33,
#       41
#      ]
#     },
#     {
#      "text": "tea",
#      "indices": [
#       42,
#       46
#      ]
#     },
#     {
#      "text": "Tea",
#      "indices": [
#       47,
#       51
#      ]
#     },
#     {
#      "text": "teaflavour",
#      "indices": [
#       52,
#       63
#      ]
#     },
#     {
#      "text": "flavoroflove",
#      "indices": [
#       64,
#       77
#      ]
#     },
#     {
#      "text": "flavouredtea",
#      "indices": [
#       78,
#       91
#      ]
#     },
#     {
#      "text": "flavour",
#      "indices": [
#       92,
#       100
#      ]
#     },
#     {
#      "text": "flavourtea",
#      "indices": [
#       101,
#       112
#      ]
#     },
#     {
#      "text": "coffeetime",
#      "indices": [
#       113,
#       124
#      ]
#     },
#     {
#      "text": "coffee",
#      "indices": [
#       125,
#       132
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "DesiKulhad",
#      "name": "Desi Kulhad Cafe",
#      "id": 1171447477083394050,
#      "id_str": "1171447477083394050",
#      "indices": [
#       3,
#       14
#      ]
#     }
#    ],
#    "urls": []
#   },
#   "metadata": {
#    "iso_language_code": "und",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 925586497847287808,
#    "id_str": "925586497847287808",
#    "name": "Shivputra Ganesh Gore",
#    "screen_name": "Shivputra_96",
#    "location": "Kurduvadi, India",
#    "description": "I\u2019m nt a #Backup Plan\n&\nDefinitely nt a #2nd choice.\n\n(Never Compromise on self-espect)",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 62,
#    "friends_count": 164,
#    "listed_count": 0,
#    "created_at": "Wed Nov 01 04:53:12 +0000 2017",
#    "favourites_count": 428,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 567,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "F5F8FA",
#    "profile_background_image_url": null,
#    "profile_background_image_url_https": null,
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/960603853862289409/4t5bl5c7_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/960603853862289409/4t5bl5c7_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/925586497847287808/1517231778",
#    "profile_link_color": "1DA1F2",
#    "profile_sidebar_border_color": "C0DEED",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": true,
#    "default_profile": true,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "retweeted_status": {
#    "created_at": "Sat Nov 16 03:03:43 +0000 2019",
#    "id": 1195537905101369344,
#    "id_str": "1195537905101369344",
#    "text": "#\u091a\u093e\u092f #\u091a\u0939\u093e #\u0936\u093e\u092f\u0930\u0940 #teacafe #tea #Tea #teaflavour #flavoroflove #flavouredtea #flavour #flavourtea #coffeetime\u2026 https://t.co/H1at4sLH1x",
#    "truncated": true,
#    "entities": {
#     "hashtags": [
#      {
#       "text": "\u091a\u093e\u092f",
#       "indices": [
#        0,
#        4
#       ]
#      },
#      {
#       "text": "\u091a\u0939\u093e",
#       "indices": [
#        5,
#        9
#       ]
#      },
#      {
#       "text": "\u0936\u093e\u092f\u0930\u0940",
#       "indices": [
#        10,
#        16
#       ]
#      },
#      {
#       "text": "teacafe",
#       "indices": [
#        17,
#        25
#       ]
#      },
#      {
#       "text": "tea",
#       "indices": [
#        26,
#        30
#       ]
#      },
#      {
#       "text": "Tea",
#       "indices": [
#        31,
#        35
#       ]
#      },
#      {
#       "text": "teaflavour",
#       "indices": [
#        36,
#        47
#       ]
#      },
#      {
#       "text": "flavoroflove",
#       "indices": [
#        48,
#        61
#       ]
#      },
#      {
#       "text": "flavouredtea",
#       "indices": [
#        62,
#        75
#       ]
#      },
#      {
#       "text": "flavour",
#       "indices": [
#        76,
#        84
#       ]
#      },
#      {
#       "text": "flavourtea",
#       "indices": [
#        85,
#        96
#       ]
#      },
#      {
#       "text": "coffeetime",
#       "indices": [
#        97,
#        108
#       ]
#      }
#     ],
#     "symbols": [],
#     "user_mentions": [],
#     "urls": [
#      {
#       "url": "https://t.co/H1at4sLH1x",
#       "expanded_url": "https://twitter.com/i/web/status/1195537905101369344",
#       "display_url": "twitter.com/i/web/status/1\u2026",
#       "indices": [
#        110,
#        133
#       ]
#      }
#     ]
#    },
#    "metadata": {
#     "iso_language_code": "und",
#     "result_type": "recent"
#    },
#    "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#    "in_reply_to_status_id": null,
#    "in_reply_to_status_id_str": null,
#    "in_reply_to_user_id": null,
#    "in_reply_to_user_id_str": null,
#    "in_reply_to_screen_name": null,
#    "user": {
#     "id": 1171447477083394050,
#     "id_str": "1171447477083394050",
#     "name": "Desi Kulhad Cafe",
#     "screen_name": "DesiKulhad",
#     "location": "Maharashtra, India",
#     "description": "\u0926\u0947\u0938\u0940 \u0915\u0941\u0932\u094d\u0939\u0921 .. \u0938\u094d\u0935\u093e\u0926 \u0905\u092a\u0928\u0947 \u092e\u093f\u091f\u094d\u091f\u0940 \u0915\u093e",
#     "url": null,
#     "entities": {
#      "description": {
#       "urls": []
#      }
#     },
#     "protected": false,
#     "followers_count": 23,
#     "friends_count": 15,
#     "listed_count": 0,
#     "created_at": "Tue Sep 10 15:37:13 +0000 2019",
#     "favourites_count": 429,
#     "utc_offset": null,
#     "time_zone": null,
#     "geo_enabled": false,
#     "verified": false,
#     "statuses_count": 106,
#     "lang": null,
#     "contributors_enabled": false,
#     "is_translator": false,
#     "is_translation_enabled": false,
#     "profile_background_color": "F5F8FA",
#     "profile_background_image_url": null,
#     "profile_background_image_url_https": null,
#     "profile_background_tile": false,
#     "profile_image_url": "http://pbs.twimg.com/profile_images/1171448905868828676/wlmo3LsC_normal.jpg",
#     "profile_image_url_https": "https://pbs.twimg.com/profile_images/1171448905868828676/wlmo3LsC_normal.jpg",
#     "profile_banner_url": "https://pbs.twimg.com/profile_banners/1171447477083394050/1568130159",
#     "profile_link_color": "1DA1F2",
#     "profile_sidebar_border_color": "C0DEED",
#     "profile_sidebar_fill_color": "DDEEF6",
#     "profile_text_color": "333333",
#     "profile_use_background_image": true,
#     "has_extended_profile": false,
#     "default_profile": true,
#     "default_profile_image": false,
#     "following": false,
#     "follow_request_sent": false,
#     "notifications": false,
#     "translator_type": "none"
#    },
#    "geo": null,
#    "coordinates": null,
#    "place": null,
#    "contributors": null,
#    "is_quote_status": false,
#    "retweet_count": 1,
#    "favorite_count": 1,
#    "favorited": false,
#    "retweeted": false,
#    "possibly_sensitive": false,
#    "lang": "und"
#   },
#   "is_quote_status": false,
#   "retweet_count": 1,
#   "favorite_count": 0,
#   "favorited": false,
#   "retweeted": false,
#   "lang": "und"
#  }
# ]

# %% [markdown]
# Twitter often returns duplicate results. We can filter them out by checking for duplicate texts using the algorithm below:

# %%
all_text = []
filtered_statuses = []

# Below iterates through each status in our statuses object (a list of dictionaries)
for s in statuses:
    
# If the text value (indexed by "text" key) is not found in our 'all_text' list, the dictionary
# is appended to our list 'filtered_statuses'. The text is also appended to our 'all_text' list, 
# meaning that if their is a duplicate status, when iterating to that status again, it will not
# be appended to our 'filtered_statuses' list as it's text will already exist in our 'all_text'
# list. Nor will the text be appended to our 'all_text' list again.
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %% [markdown]
# By rechecking the len of our statuses list, we can see if the number reduced. If so - duplicates existed, and are no longer included in the list.

# %%
len(statuses)
# Out:
# 75

# %% [markdown]
# Below we iterate through our list of dictionaries in our returned status search results and return the text for each of the status dictionaries from the list in to a new list using list comprehension.

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['It’s funny how you’ll ignore me for hours, butttt if it’s someone you want to fuck or interested in you’re still li… https://t.co/62b0FaTsrl',
#  'Fraser takes making a fish tea very seriously... And literally.\n\n#toddler #cooking #fish #tea #fishtea #glasgow… https://t.co/8LOexe2Gz2',
#  '@costacoffee time #MummyAndSon #Breakfast #Tea #SausageBap #Family #TimeTogether #ActuallyHisIdea ! https://t.co/Jg7qEPFyOF',
#  'Winter days and Tea!!\nAlways a better love story!!\n#Tea #Love https://t.co/xcxB7wudqS',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @Grupo_Aitana: A menudo los niños con #TEA son detectados por la presencia de problemas de conducta #aitana2019 https://t.co/MSzYVKAPAJ',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @CerebrodeMaria: Os voy a contar algo porque me apetece.\nComo sabéis algunos todos los días mi hijo #TEA y yo vamos y venimos del cole e…',
#  'Have a beautiful weekend, and stop by Cafe Cosmos. Enjoy organic free-trade coffee, espresso &amp; tea &amp; quality beer.… https://t.co/IvecV2KNyK',
#  'RT @albertofilologi: #FelizSabado Buenos días¡ Seguimos creciendo en @Samaria_Social con la prestación de servicios en el ámbito #sociosani…',
#  'Morning \n\nhttps://t.co/RMImyjaThK\n#earlybiz #ukgifthour #tea #coffee #SaturdayMorning https://t.co/4Wr2cJRINs',
#  'RT @LoriShemek: All teas are excellent for your health due to the antioxidant properties of tea flavonoids, however, these 3 are tops in te…',
#  'RT @CerebrodeMaria: Os voy a contar algo porque me apetece.\nComo sabéis algunos todos los días mi hijo #TEA y yo vamos y venimos del cole e…',
#  'RT @JJM_Ealing: With the weather turning a little #chilly for your morning commute Why not start the day with a lovely cup of #tea or #coff…',
#  'Hire me for your bespoke #tea leaf reading!\nGet in touch with your #requirements\n\n#henparty #leavingdo #wedding… https://t.co/CfHhZwnO5q',
#  'RT @ssh4net: #japan #tea #cats https://t.co/L2k1YtxJAT',
#  'RT @SEPEAP: Detección precoz del trastorno del espectro autista #TEA durante el primer año de vida en la consulta pediátrica #pediatriaInte…',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'With the weather turning a little #chilly for your morning commute Why not start the day with a lovely cup of #tea… https://t.co/pag1jkCCC2',
#  'RT @JJM_Ealing: @InOscars on #MyHighStreet &amp; @TheGBHighSt winners #Pitshanger #GBHighSt #PitshangerLane are getting ready for #Christmas 🎄…',
#  'RT @MillyGreenLtd: ☕ WIN ☕ COMPETITION TIME ~ Countdown to Christmas in style with a chance to win one of our #HaveAHappyChristmas tea adve…',
#  '#FelizSabado Buenos días¡ Seguimos creciendo en @Samaria_Social con la prestación de servicios en el ámbito… https://t.co/RqW6WVr9n8',
#  '@InOscars on #MyHighStreet &amp; @TheGBHighSt winners #Pitshanger #GBHighSt #PitshangerLane are getting ready for… https://t.co/klR6wergkq',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'どんなに講釈を言おうが、紅茶も人の口に入る食品です、農産加工品です。保存がききますが、マグロやうどんと同じです。美味しい物は美味しい、不味い物は不味い！です。どうにも誤魔化すことが出来ないものの一つが「味」です。ROWAN創業以来の方針です。\n\n#紅茶 #tea #食品 #飲み物',
#  '#cats #tea #japan https://t.co/UXntl8GK7W',
#  '#japan #tea #cats https://t.co/L2k1YtxJAT',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @masood_619_: جو مزا رات کے ایک بجے چائے پینے کا ہے نا، وہ بالکل الگ ہے ☕\n#LateNight #Tea https://t.co/T4hjPWfvJD',
#  'Hafta sonu başladığına göre, güne erkenden başlayıp  kahvaltısını doya doya yapmayan kalmasın! 😍\n#benimkeifim… https://t.co/vWdHBnpnJb',
#  'RT @CerebrodeMaria: Os voy a contar algo porque me apetece.\nComo sabéis algunos todos los días mi hijo #TEA y yo vamos y venimos del cole e…',
#  "Supercharged equipment for #education #learning #ideas #learn4life Eduporium: With us, it's Teacher Appreciation We… https://t.co/truJcwxMuZ",
#  'Fragrant and invigorating, there are certain #concoctions that seem like #tea but are far from it https://t.co/VDrBBkHuJT',
#  'Give Freya a warm welcome for her first event back in London, following a five-months residency in Copenhagen\nBook… https://t.co/aLn57PO16F',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'The Tea of Assam Its Heritage, Uniqueness and Challenges of the Industry\n\nSee: https://t.co/JKLRiquSW5\n\n@isrgrajan… https://t.co/kz01510SZ4',
#  'RT @LoriShemek: All teas are excellent for your health due to the antioxidant properties of tea flavonoids, however, these 3 are tops in te…',
#  'Saturday: A day of reflection, a day of journaling, a day of preparing and packing. But for now I will sit back and… https://t.co/ssUCGvo2fh',
#  'Cooknook Kitchen presenting #paratha #roll #chicken #pasta  and #tea at Event "Essential Etiquette of a Muslimah" a… https://t.co/yCKN5ZUV5D',
#  'RT @tommyd49: Asim’s Extraordinary Journeys 5star Fantasy Adventure https://t.co/panhUvolT8 #action #adventure #novel #fictionbooks #younga…',
#  'Cooknook Kitchen @cooknook.kitchen.2016 presenting #paratha #roll #chicken #pasta  and #tea at Event "Essential Eti… https://t.co/XzElOlYWlE',
#  'Cooknook Kitchen presenting #paratha #roll #chicken #pasta  and #tea at Event "Essential Etiquette of a Muslimah" a… https://t.co/lCQ0MCct09',
#  'Tea people step this way, your new Tea Leaf Reading events are coming!\n\n@StowBrothers\nPhoto by Jason Leung\n#Tea… https://t.co/dGOlerdEfY',
#  'Restaurant - Take Away - Venue Hire\n\nOpen from 12pm till late (Lunch menu 12pm to 4pm)\nINDO-CHINESE . TAWA . GRILL… https://t.co/THTQdeggIc',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @tea__365: 1990년대 초반, 손의순 차창의 육안차입니다.\n이 차는 선물로 받았습니다.🎁\n\n육안차는 흑차와 보이차의 제다법이 함께 쓰였습니다. \n어두운 차의 수색에 비해 맑은 단맛, 흑차 특유의 띄운향, 입안을 톡톡톡 쏘는듯한 느낌이…',
#  'RT @Nazdeek1: Discussions happening on how this new code will subsume and change provisions under the Plantation Labour Act. #tea #workers…',
#  'E N E R G Y  T E A🔋 \nDitch the coffee for a more effective, natural caffeine boost with no energy crash 🧘🏼\u200d♀️\nGreat… https://t.co/53ZCI5EeV6',
#  'Detección precoz del trastorno del espectro autista #TEA durante el primer año de vida en la consulta pediátrica… https://t.co/7KX10H1lXH',
#  'RT @HumbleAttitude1: Tea is always a good idea) this #design is available in my @teepublic store\n#tealover #tea #teatime #hoodie #tee #ones…',
#  'ભાવ-વધારો / રેલવેએ ટ્રેનમાં મળતા ચા, નાસ્તા અને જમવાના ભાવમાં વધારો કર્યો; ફર્સ્ટ ACના પેસેન્જર્સે ચા માટે રૂ.35 ચૂ… https://t.co/D6rn2IwlLS',
#  'RT @CerebrodeMaria: Os voy a contar algo porque me apetece.\nComo sabéis algunos todos los días mi hijo #TEA y yo vamos y venimos del cole e…',
#  'นี่ไม่รู้จะขอบคุณช่อง @Mono29TV ยังไงดี ที่เอามาดามมาฉายในซีซั่น5 เป็นอะไรที่ตอบโจทย์ได้ดีมาก ถึงแม้ใน Ep.5 จะเกี่ย… https://t.co/iFZFl8jR5l',
#  'RT @windyhollowscot: On my wander I came across this lovely little  #leaf with beautiful #icecrystals 🍃a #frosty young #blackthorn ❄️ #your…',
#  'RT @5stocksinto: 5 Indian Stocks Into Tea https://t.co/By6pRBXHym #India #tea #Stocks #beverages  #assam #agriculture #farming #commodities…',
#  'RT @Nazdeek1: Discussions happening on how this new code will subsume and change provisions under the Plantation Labour Act. #tea #workers…',
#  'Discussions happening on how this new code will subsume and change provisions under the Plantation Labour Act. #tea… https://t.co/FtZxD8w2yX',
#  "For this weekend. I'll have this cup of herbal tea, and be waiting for the next weekend.\n\u2060\n#weekend #herbaltea… https://t.co/qXrYPflIp4",
#  'RT @LoriShemek: All teas are excellent for your health due to the antioxidant properties of tea flavonoids, however, these 3 are tops in te…',
#  "RT @PierrePetrou: It's nine years ago today that my Godson, #Charlie died from a #Brain Tumour. Charlie was only 7-years old, but will alwa…",
#  'RT @omotesando_info: 今日は（も？）表参道のティーサロン「サロン・ド・テ・ラヴォンド」さんで紅茶三昧な1日でした( ･ิω･ิ)b✧\n\nhttps://t.co/NvQ55UN9Pg\n\n#紅茶 #ミルクティー #黒烏龍茶 #フルーツティー #パンケーキ #表…',
#  'Jitanue ukiwa na chap food app \n#jitanue #tea #breakfasttime \nAgiza hapa sasahivi https://t.co/uC9l27Srjj https://t.co/TkJJsxwDae',
#  'RT @worldrhymeweek: Polly is here and is offering to make hot drinks, what are you all having? #tea #coffee #pollyputthekettleon #milknosug…',
#  'RT @worldrhymeweek: Polly is here and is offering to make hot drinks, what are you all having? #tea #coffee #pollyputthekettleon #milknosug…',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'Finally, the stretch of wait is over for tea lovers. The brand new store of Chai Chun opens its doors at Dimapur. H… https://t.co/k9nzSj5txh',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @MillyGreenLtd: ☕ WIN ☕ COMPETITION TIME ~ Countdown to Christmas in style with a chance to win one of our #HaveAHappyChristmas tea adve…',
#  "RT @Tyler_S_Page: Ok whoever invented #CoffeeBags (@Taylors ) need locking up! Stick to #Tea don't spoil #Coffee by putting it into bags th…",
#  'RT @LoriShemek: All teas are excellent for your health due to the antioxidant properties of tea flavonoids, however, these 3 are tops in te…',
#  'Beautiful #darband #Iran  #chai #tea #sugarcubes #mountains https://t.co/LmIdGJ50MR',
#  'RT @ParishDMartyrs: A wonderful start to (a slightly drizzly) #lumiere #lumiere2019 at St Godric’sChurch. Refreshments are available in our…',
#  'RT @Always_Gr8_Buys: Empire Bites Back parody mug! Calling all dog and Star Wars lovers! #StarWars #doglovers #coffee #tea #EmpireStrikesBa…',
#  'Enjoy Our weekend #breakfast open #buffet every fri &amp; sat morning 8am-11am @themrestaurant Bahrain!\n#weekendvibes… https://t.co/bGfFtFS2KL',
#  "It's amazing day, finally the package is arrive and I can eat them all if I can do that.\n.\n.\n.\n.\n#post #foodaddict… https://t.co/7wIm84AynV",
#  'RT @pereira_marce: 💙💙Para los q esten en las marchas y hacen q el q baila pasa. respeten si llevan pañuelo azul ahi viaja una persona con a…',
#  'RT @MATalibli: Happy to present an #Azerbaijan|i traditional #tea set &amp; carpet as #ACD Annual Gala ruffle prize ! Good luck 🍀 ;) https://t.…',
#  'Fun fact: Each cup of Dilmah tea contains around 30 artisanally manufactured, high quality tea leaves. 🌱 #funfacts… https://t.co/THXoXQoU0j',
#  'This time next year we will all be able to claim a free sex robot, I hope mine can also make the tea afterwards...… https://t.co/OTNnmh8eM3',
#  "RT @vikaskumar: Yes that's true as #tea is #love... #life #tealovers #himachali https://t.co/xeji8LMYiW",
#  'RT @CerebrodeMaria: Os voy a contar algo porque me apetece.\nComo sabéis algunos todos los días mi hijo #TEA y yo vamos y venimos del cole e…',
#  'RT @KMennerFineArt: #GEMINI #TEA #ROSE #Nature #Photography Quality Prints Products at: https://t.co/YgLMrXEokE',
#  'RT @Marie_ORourke: Tea time ⏱\n#tea #afternoontea #books #booksandtea https://t.co/eXgKppWGrL',
#  'Curious about tea? Click this link to get three Tea Journey magazine articles per month https://t.co/eCupX6Vy4F Ser… https://t.co/pQFg8nymkl',
#  'RT @MATalibli: Happy to present an #Azerbaijan|i traditional #tea set &amp; carpet as #ACD Annual Gala ruffle prize ! Good luck 🍀 ;) https://t.…',
#  '#GEMINI #TEA #ROSE #Nature #Photography Quality Prints Products at: https://t.co/YgLMrXEokE',
#  "Yes that's true as #tea is #love... #life #tealovers #himachali https://t.co/xeji8LMYiW",
#  'RT @MyJapanvideo: [Curator\'s Choice] by https://t.co/2uGHjICgln\n #Murakami City, which also called "The tea country at the northern limit",…',
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  "#marvel #thirsty #thirstisREAL #mbj #michealbjordan #tea \nI'M GONNA DIE\n… .. thank you🤣😂🤣😂🤣😂🤣😂🤣\n\nUs white skin peop… https://t.co/nCdEkd53J4",
#  'RT @dorset_tea: Happy Freebie Friday! Our friends at Make International have given us 4 of these fantastic mugs to giveaway. For your chanc…',
#  'RT @tea__365: 1990년대 초반, 손의순 차창의 육안차입니다.\n이 차는 선물로 받았습니다.🎁\n\n육안차는 흑차와 보이차의 제다법이 함께 쓰였습니다. \n어두운 차의 수색에 비해 맑은 단맛, 흑차 특유의 띄운향, 입안을 톡톡톡 쏘는듯한 느낌이…',
#  '1990년대 초반, 손의순 차창의 육안차입니다.\n이 차는 선물로 받았습니다.🎁\n\n육안차는 흑차와 보이차의 제다법이 함께 쓰였습니다. \n어두운 차의 수색에 비해 맑은 단맛, 흑차 특유의 띄운향, 입안을 톡톡톡… https://t.co/p4w7Yfpro9',
#  '#Rancabali, two hours drive southwest of #Bandung.\n\nBeautiful #tea plantations from the Dutch era, on the fertile w… https://t.co/ni42VZC9NE',
#  'RT @indiradairy: ഐഡി തൈര് നല്ല ദഹനത്തിനായി നന്മയുടെ സ്വാദ്\nTeam ID MILK - Indira Dairy Products\n\n✨✨✨✨✨✨✨✨✨✨\n#tea #dairy #farm #milk #cow #f…',
#  'RT @indiradairy: ഐഡി തൈര് നല്ല ദഹനത്തിനായി നന്മയുടെ സ്വാദ്\nTeam ID MILK - Indira Dairy Products\n\n✨✨✨✨✨✨✨✨✨✨\n#tea #dairy #farm #milk #cow #f…',
#  'RT @pereira_marce: 💙💙Para los q esten en las marchas y hacen q el q baila pasa. respeten si llevan pañuelo azul ahi viaja una persona con a…',
#  '@MomWifeHustler What is CBD? #CBD free education in under 2 mins  https://t.co/mRDptXh9qk \nCBD free education &amp; pur… https://t.co/P1n1AYWJum',
#  'RT @DesiKulhad: #चाय #चहा #शायरी #teacafe #tea #Tea #teaflavour #flavoroflove #flavouredtea #flavour #flavourtea #coffeetime #coffee #coffe…']

# %% [markdown]
# Below we show one sample search result by slicing the list. This is a great way to get an insight to the structure of retrieved JSON data, and how you can go about extracting specific data from it.

# %%
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sat Nov 16 08:37:16 +0000 2019",
#  "id": 1195621846705684482,
#  "id_str": "1195621846705684482",
#  "text": "But First, Coffee...\n. \n.\n.\n\u2764\ufe0f\u2615\ufe0f .\n. .\n. .\n.\n.\n.\n\n#alty #brunch #poachedeggs #bagel #smashedavocado \n#altrincham\u2026 https://t.co/4n0c2Ts2qM",
#  "truncated": true,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "alty",
#     "indices": [
#      50,
#      55
#     ]
#    },
#    {
#     "text": "brunch",
#     "indices": [
#      56,
#      63
#     ]
#    },
#    {
#     "text": "poachedeggs",
#     "indices": [
#      64,
#      76
#     ]
#    },
#    {
#     "text": "bagel",
#     "indices": [
#      77,
#      83
#     ]
#    },
#    {
#     "text": "smashedavocado",
#     "indices": [
#      84,
#      99
#     ]
#    },
#    {
#     "text": "altrincham",
#     "indices": [
#      101,
#      112
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/4n0c2Ts2qM",
#     "expanded_url": "https://twitter.com/i/web/status/1195621846705684482",
#     "display_url": "twitter.com/i/web/status/1\u2026",
#     "indices": [
#      114,
#      137
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2860598996,
#   "id_str": "2860598996",
#   "name": "California Coffee & Wine",
#   "screen_name": "CaliCoffeeWine",
#   "location": "Altrincham, Cheshire",
#   "description": "#MakeCoffeeGreatAgain\u2615\ufe0f",
#   "url": "https://t.co/lz9w4bb2gJ",
#   "entities": {
#    "url": {
#     "urls": [
#      {
#       "url": "https://t.co/lz9w4bb2gJ",
#       "expanded_url": "http://californiacoffee.co.uk",
#       "display_url": "californiacoffee.co.uk",
#       "indices": [
#        0,
#        23
#       ]
#      }
#     ]
#    },
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 494,
#   "friends_count": 246,
#   "listed_count": 34,
#   "created_at": "Fri Oct 17 15:19:39 +0000 2014",
#   "favourites_count": 1184,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 2719,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "000000",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1047249952618033153/qbkIdDnd_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1047249952618033153/qbkIdDnd_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2860598996/1538517979",
#   "profile_link_color": "1B95E0",
#   "profile_sidebar_border_color": "000000",
#   "profile_sidebar_fill_color": "000000",
#   "profile_text_color": "000000",
#   "profile_use_background_image": false,
#   "has_extended_profile": true,
#   "default_profile": false,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": {
#   "type": "Point",
#   "coordinates": [
#    53.38360994,
#    -2.35159993
#   ]
#  },
#  "coordinates": {
#   "type": "Point",
#   "coordinates": [
#    -2.35159993,
#    53.38360994
#   ]
#  },
#  "place": {
#   "id": "74790dfe0c08c72f",
#   "url": "https://api.twitter.com/1.1/geo/id/74790dfe0c08c72f.json",
#   "place_type": "city",
#   "name": "Sale",
#   "full_name": "Sale, England",
#   "country_code": "GB",
#   "country": "United Kingdom",
#   "contained_within": [],
#   "bounding_box": {
#    "type": "Polygon",
#    "coordinates": [
#     [
#      [
#       -2.3798084,
#       53.358611
#      ],
#      [
#       -2.2737406,
#       53.358611
#      ],
#      [
#       -2.2737406,
#       53.4417876
#      ],
#      [
#       -2.3798084,
#       53.4417876
#      ]
#     ]
#    ]
#   },
#   "attributes": {}
#  },
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the below list comprehension is a list with only one element that can be accessed
# by its index and set to the variable t.
# [ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

t = statuses[0]

# Explore the variable t to get familiarized with the data structure...
print(t.keys())
print(t['coordinates'])
print(t['text'])
print(t['retweet_count'])
print(t['retweeted'])
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])
# {'type': 'Point', 'coordinates': [-2.35159993, 53.38360994]}
# But First, Coffee...
# .
# .
# .
# ❤️☕️ .
# . .
# . .
# .
# .
# .
#
# #alty #brunch #poachedeggs #bagel #smashedavocado
# #altrincham… https://t.co/4n0c2Ts2qM
# 0
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])

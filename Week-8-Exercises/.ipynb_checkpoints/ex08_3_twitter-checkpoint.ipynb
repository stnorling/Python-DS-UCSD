# %% [markdown]
# # Exercise Notebook on Accessing Twitter

# %% [markdown]
# ## Exercise 1: Twitter API Access
#
# You should already have Twitter access setup for the lecture, if you do not, please revisit the lecture and make sure you have your Twitter credentials saved:

# %%
import pickle
import os

# %% [markdown]
# Make sure to select the relative path to the `secret_twitter_credentials.pkl` file:
#
# Remember `.pkl` files are files that can be Python data structures, saved on to disk, so that they can be accessed at a later date. In this case, the saved data structure is a Python dictionary containing the necessary authorisation details to connect to Twitter's API.
#
# We must load the file using 'rb' to read the file bytes (deserialization), as it has been previously serialized.

# %%
twitter_auth=pickle.load(open('../Week-8-NLP-Databases/secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# We connect to the Twitter API by first creating a twitter.oauth.Oauth object, containing our credentials. We then use the twitter.Twitter method, setting the auth kwarg to the Oauth object we've just created, and assign this to a variable. This variable is a twitter API object which we can now use to start accessing Twitter's data.

# %%
import twitter

auth = twitter.oauth.OAuth(twitter_auth['Access Token'],
                           twitter_auth['Access Token Secret'],
                           twitter_auth['Consumer Key'],
                           twitter_auth['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ## Exercise 2: Get the WOE ID for a place of interest

# %% [markdown]
# Find the Yahoo! Where On Earth ID for a place you are interested in at:
#
# http://woeid.rosselliot.co.nz/
#
# Set `LOCAL_WOE_ID` to this integer number below:

# %%
LOCAL_WOE_ID = None
### BEGIN SOLUTION
LOCAL_WOE_ID = '23424916'
### END SOLUTION

# %% [markdown]
# Passing a variable in to a Python `assert` statement checks if the variable is assigned a value other than None. Triggers the assertion error msg if the variables value is None.

# %%
assert LOCAL_WOE_ID, "Remember to set LOCAL_WOE_ID to a location identifier"

# %% [markdown]
# ## Exercise 3: Retrieve and print local trends
#
# Let's use the twitter API to retrieve trends. We do this using the `.trends.place()` method and passing in our WOE id to the _id kwarg. We are returned a TwitterListResponse.

# %%
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %% [markdown]
# `local_trends` is a highly nested data structure made up of lists and dictionaries, explore it with `type()`, `len()` and indexing like `[0]` and print out a list of all the trends:

# %%
print(len(local_trends[0]['trends']))
local_trends[0]['trends']
# Out:
# 50
# [{'name': '#DemDebate',
#   'url': 'http://twitter.com/search?q=%23DemDebate',
#   'promoted_content': None,
#   'query': '%23DemDebate',
#   'tweet_volume': 642984},
#  {'name': 'nick smith',
#   'url': 'http://twitter.com/search?q=%22nick+smith%22',
#   'promoted_content': None,
#   'query': '%22nick+smith%22',
#   'tweet_volume': None},
#  {'name': '#NZvENG',
#   'url': 'http://twitter.com/search?q=%23NZvENG',
#   'promoted_content': None,
#   'query': '%23NZvENG',
#   'tweet_volume': None},
#  {'name': '#HiNZ2019',
#   'url': 'http://twitter.com/search?q=%23HiNZ2019',
#   'promoted_content': None,
#   'query': '%23HiNZ2019',
#   'tweet_volume': None},
#  {'name': 'grammy',
#   'url': 'http://twitter.com/search?q=grammy',
#   'promoted_content': None,
#   'query': 'grammy',
#   'tweet_volume': 1086141},
#  {'name': '#22OpeningDay',
#   'url': 'http://twitter.com/search?q=%2322OpeningDay',
#   'promoted_content': None,
#   'query': '%2322OpeningDay',
#   'tweet_volume': None},
#  {'name': '#FordTrophy',
#   'url': 'http://twitter.com/search?q=%23FordTrophy',
#   'promoted_content': None,
#   'query': '%23FordTrophy',
#   'tweet_volume': None},
#  {'name': 'Grace Millane',
#   'url': 'http://twitter.com/search?q=%22Grace+Millane%22',
#   'promoted_content': None,
#   'query': '%22Grace+Millane%22',
#   'tweet_volume': None},
#  {'name': 'Test',
#   'url': 'http://twitter.com/search?q=Test',
#   'promoted_content': None,
#   'query': 'Test',
#   'tweet_volume': 277269},
#  {'name': 'Spurs',
#   'url': 'http://twitter.com/search?q=Spurs',
#   'promoted_content': None,
#   'query': 'Spurs',
#   'tweet_volume': 190326},
#  {'name': 'Winston',
#   'url': 'http://twitter.com/search?q=Winston',
#   'promoted_content': None,
#   'query': 'Winston',
#   'tweet_volume': 12965},
#  {'name': 'Jose',
#   'url': 'http://twitter.com/search?q=Jose',
#   'promoted_content': None,
#   'query': 'Jose',
#   'tweet_volume': 487194},
#  {'name': 'dave rennie',
#   'url': 'http://twitter.com/search?q=%22dave+rennie%22',
#   'promoted_content': None,
#   'query': '%22dave+rennie%22',
#   'tweet_volume': None},
#  {'name': 'Minister',
#   'url': 'http://twitter.com/search?q=Minister',
#   'promoted_content': None,
#   'query': 'Minister',
#   'tweet_volume': 214872},
#  {'name': 'Peters',
#   'url': 'http://twitter.com/search?q=Peters',
#   'promoted_content': None,
#   'query': 'Peters',
#   'tweet_volume': 16523},
#  {'name': 'Poch',
#   'url': 'http://twitter.com/search?q=Poch',
#   'promoted_content': None,
#   'query': 'Poch',
#   'tweet_volume': 51813},
#  {'name': 'Stephen Colbert',
#   'url': 'http://twitter.com/search?q=%22Stephen+Colbert%22',
#   'promoted_content': None,
#   'query': '%22Stephen+Colbert%22',
#   'tweet_volume': None},
#  {'name': 'tottenham',
#   'url': 'http://twitter.com/search?q=tottenham',
#   'promoted_content': None,
#   'query': 'tottenham',
#   'tweet_volume': 205131},
#  {'name': 'sondland',
#   'url': 'http://twitter.com/search?q=sondland',
#   'promoted_content': None,
#   'query': 'sondland',
#   'tweet_volume': 2453521},
#  {'name': 'nunes',
#   'url': 'http://twitter.com/search?q=nunes',
#   'promoted_content': None,
#   'query': 'nunes',
#   'tweet_volume': 547746},
#  {'name': 'mike hosking',
#   'url': 'http://twitter.com/search?q=%22mike+hosking%22',
#   'promoted_content': None,
#   'query': '%22mike+hosking%22',
#   'tweet_volume': None},
#  {'name': 'NZ First',
#   'url': 'http://twitter.com/search?q=%22NZ+First%22',
#   'promoted_content': None,
#   'query': '%22NZ+First%22',
#   'tweet_volume': None},
#  {'name': 'wallabies',
#   'url': 'http://twitter.com/search?q=wallabies',
#   'promoted_content': None,
#   'query': 'wallabies',
#   'tweet_volume': None},
#  {'name': 'LinkedIn',
#   'url': 'http://twitter.com/search?q=LinkedIn',
#   'promoted_content': None,
#   'query': 'LinkedIn',
#   'tweet_volume': 53614},
#  {'name': 'winnie',
#   'url': 'http://twitter.com/search?q=winnie',
#   'promoted_content': None,
#   'query': 'winnie',
#   'tweet_volume': None},
#  {'name': 'Disney',
#   'url': 'http://twitter.com/search?q=Disney',
#   'promoted_content': None,
#   'query': 'Disney',
#   'tweet_volume': 275648},
#  {'name': 'deputy pm',
#   'url': 'http://twitter.com/search?q=%22deputy+pm%22',
#   'promoted_content': None,
#   'query': '%22deputy+pm%22',
#   'tweet_volume': None},
#  {'name': 'Tauranga',
#   'url': 'http://twitter.com/search?q=Tauranga',
#   'promoted_content': None,
#   'query': 'Tauranga',
#   'tweet_volume': None},
#  {'name': 'Flat Bush',
#   'url': 'http://twitter.com/search?q=%22Flat+Bush%22',
#   'promoted_content': None,
#   'query': '%22Flat+Bush%22',
#   'tweet_volume': None},
#  {'name': 'Timaru',
#   'url': 'http://twitter.com/search?q=Timaru',
#   'promoted_content': None,
#   'query': 'Timaru',
#   'tweet_volume': None},
#  {'name': 'kiwibuild',
#   'url': 'http://twitter.com/search?q=kiwibuild',
#   'promoted_content': None,
#   'query': 'kiwibuild',
#   'tweet_volume': None},
#  {'name': 'Wrong',
#   'url': 'http://twitter.com/search?q=Wrong',
#   'promoted_content': None,
#   'query': 'Wrong',
#   'tweet_volume': 720386},
#  {'name': 'united',
#   'url': 'http://twitter.com/search?q=united',
#   'promoted_content': None,
#   'query': 'united',
#   'tweet_volume': 420241},
#  {'name': 'coldplay',
#   'url': 'http://twitter.com/search?q=coldplay',
#   'promoted_content': None,
#   'query': 'coldplay',
#   'tweet_volume': 25249},
#  {'name': 'goty',
#   'url': 'http://twitter.com/search?q=goty',
#   'promoted_content': None,
#   'query': 'goty',
#   'tweet_volume': 15049},
#  {'name': 'Dems',
#   'url': 'http://twitter.com/search?q=Dems',
#   'promoted_content': None,
#   'query': 'Dems',
#   'tweet_volume': 291208},
#  {'name': 'andrew little',
#   'url': 'http://twitter.com/search?q=%22andrew+little%22',
#   'promoted_content': None,
#   'query': '%22andrew+little%22',
#   'tweet_volume': None},
#  {'name': '#impeachmenthearing',
#   'url': 'http://twitter.com/search?q=%23impeachmenthearing',
#   'promoted_content': None,
#   'query': '%23impeachmenthearing',
#   'tweet_volume': 259647},
#  {'name': '#Paedsoc2019',
#   'url': 'http://twitter.com/search?q=%23Paedsoc2019',
#   'promoted_content': None,
#   'query': '%23Paedsoc2019',
#   'tweet_volume': None},
#  {'name': '#futureofwork',
#   'url': 'http://twitter.com/search?q=%23futureofwork',
#   'promoted_content': None,
#   'query': '%23futureofwork',
#   'tweet_volume': None},
#  {'name': '#thisisbts',
#   'url': 'http://twitter.com/search?q=%23thisisbts',
#   'promoted_content': None,
#   'query': '%23thisisbts',
#   'tweet_volume': 1109890},
#  {'name': '#nzqt',
#   'url': 'http://twitter.com/search?q=%23nzqt',
#   'promoted_content': None,
#   'query': '%23nzqt',
#   'tweet_volume': None},
#  {'name': '#wellingtonparanormal',
#   'url': 'http://twitter.com/search?q=%23wellingtonparanormal',
#   'promoted_content': None,
#   'query': '%23wellingtonparanormal',
#   'tweet_volume': None},
#  {'name': '#nzmadeday',
#   'url': 'http://twitter.com/search?q=%23nzmadeday',
#   'promoted_content': None,
#   'query': '%23nzmadeday',
#   'tweet_volume': None},
#  {'name': '#ndfnz',
#   'url': 'http://twitter.com/search?q=%23ndfnz',
#   'promoted_content': None,
#   'query': '%23ndfnz',
#   'tweet_volume': None},
#  {'name': '#ReadyToRun',
#   'url': 'http://twitter.com/search?q=%23ReadyToRun',
#   'promoted_content': None,
#   'query': '%23ReadyToRun',
#   'tweet_volume': None},
#  {'name': '#xeroroadshow',
#   'url': 'http://twitter.com/search?q=%23xeroroadshow',
#   'promoted_content': None,
#   'query': '%23xeroroadshow',
#   'tweet_volume': None},
#  {'name': '#BB13',
#   'url': 'http://twitter.com/search?q=%23BB13',
#   'promoted_content': None,
#   'query': '%23BB13',
#   'tweet_volume': 160519},
#  {'name': '#DF19',
#   'url': 'http://twitter.com/search?q=%23DF19',
#   'promoted_content': None,
#   'query': '%23DF19',
#   'tweet_volume': 18558},
#  {'name': '#christchurch',
#   'url': 'http://twitter.com/search?q=%23christchurch',
#   'promoted_content': None,
#   'query': '%23christchurch',
#   'tweet_volume': None}]

# %% [markdown]
# Using list comprehension we can easily extract the trending tweet names in to a list.

# %%
list_of_trends = None
### BEGIN SOLUTION
list_of_trends = [x['name'] for x in local_trends[0]['trends']]
### END SOLUTION
list_of_trends
# Out:
# ['#DemDebate',
#  'nick smith',
#  '#NZvENG',
#  '#HiNZ2019',
#  'grammy',
#  '#22OpeningDay',
#  '#FordTrophy',
#  'Grace Millane',
#  'Test',
#  'Spurs',
#  'Winston',
#  'Jose',
#  'dave rennie',
#  'Minister',
#  'Peters',
#  'Poch',
#  'Stephen Colbert',
#  'tottenham',
#  'sondland',
#  'nunes',
#  'mike hosking',
#  'NZ First',
#  'wallabies',
#  'LinkedIn',
#  'winnie',
#  'Disney',
#  'deputy pm',
#  'Tauranga',
#  'Flat Bush',
#  'Timaru',
#  'kiwibuild',
#  'Wrong',
#  'united',
#  'coldplay',
#  'goty',
#  'Dems',
#  'andrew little',
#  '#impeachmenthearing',
#  '#Paedsoc2019',
#  '#futureofwork',
#  '#thisisbts',
#  '#nzqt',
#  '#wellingtonparanormal',
#  '#nzmadeday',
#  '#ndfnz',
#  '#ReadyToRun',
#  '#xeroroadshow',
#  '#BB13',
#  '#DF19',
#  '#christchurch']

# %% [markdown]
# `isinstance(obj, class_or_tuple)` is a Python method that returns whether an object is an instance of a class or of a subclass thereof.

# %%
assert isinstance(list_of_trends, list), "list_of_trends should be a list"

# %% [markdown]
# ## Exercise 4: Collecting search results
#
# Now let's execute a search on Twitter for the most popular trend and repeat the filtering step performed during the lectures to remove duplicate results.
#
# Set the `q` variable to the most popular trend in the list we retrieved above:

# %%
q = None
### BEGIN SOLUTION
q='#wellingtonparanormal'
### END SOLUTION

# %% [markdown]
# Then let's execute the Twitter search. We do this using the `.search.tweets(q, count)` and pass in the hashtag we're searching for to the q kwarg, and set the count kwarg to the maximum number of tweets we'd like to return.

# %%
# DO NOT MODIFY
count = 100

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']
print(len(statuses))
statuses
# Out:
# 100
# [{'created_at': 'Thu Nov 21 05:24:13 +0000 2019',
#   'id': 1197385202781302784,
#   'id_str': '1197385202781302784',
#   'text': 'I watched S02E06 of Wellington Paran...! #wellingtonparanormal  #tvtime https://t.co/EbRJpP0GYS https://t.co/3S3uJXKXs3',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#      'indices': [41, 62]},
#     {'text': 'tvtime', 'indices': [64, 71]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/EbRJpP0GYS',
#      'expanded_url': 'https://tvtime.com/r/1dNKN',
#      'display_url': 'tvtime.com/r/1dNKN',
#      'indices': [72, 95]}],
#    'media': [{'id': 1197385200591880194,
#      'id_str': '1197385200591880194',
#      'indices': [96, 119],
#      'media_url': 'http://pbs.twimg.com/media/EJ33fvSWwAIpHA2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJ33fvSWwAIpHA2.jpg',
#      'url': 'https://t.co/3S3uJXKXs3',
#      'display_url': 'pic.twitter.com/3S3uJXKXs3',
#      'expanded_url': 'https://twitter.com/JoshAllwein/status/1197385202781302784/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 525, 'h': 295, 'resize': 'fit'},
#       'large': {'w': 525, 'h': 295, 'resize': 'fit'},
#       'medium': {'w': 525, 'h': 295, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1197385200591880194,
#      'id_str': '1197385200591880194',
#      'indices': [96, 119],
#      'media_url': 'http://pbs.twimg.com/media/EJ33fvSWwAIpHA2.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJ33fvSWwAIpHA2.jpg',
#      'url': 'https://t.co/3S3uJXKXs3',
#      'display_url': 'pic.twitter.com/3S3uJXKXs3',
#      'expanded_url': 'https://twitter.com/JoshAllwein/status/1197385202781302784/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 525, 'h': 295, 'resize': 'fit'},
#       'large': {'w': 525, 'h': 295, 'resize': 'fit'},
#       'medium': {'w': 525, 'h': 295, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://www.tvtime.com" rel="nofollow">TV Time, TV show tracker</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 20077177,
#    'id_str': '20077177',
#    'name': 'Josh Allwein',
#    'screen_name': 'JoshAllwein',
#    'location': 'Colorado Springs, Planet Earth',
#    'description': 'Professional dragon slayer and musician. I am also an aspiring movie & TV writer... Please follow my band @Stavesail!',
#    'url': 'https://t.co/N73M60zkjJ',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/N73M60zkjJ',
#        'expanded_url': 'http://wattpad.com/user/joshallwein',
#        'display_url': 'wattpad.com/user/joshallwe…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 154,
#    'friends_count': 324,
#    'listed_count': 7,
#    'created_at': 'Wed Feb 04 18:30:14 +0000 2009',
#    'favourites_count': 8,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 191,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1144689899838279681/3YblWMUC_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1144689899838279681/3YblWMUC_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/20077177/1561749796',
#    'profile_link_color': 'C2790B',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '363636',
#    'profile_text_color': '9DC3E4',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Thu Nov 21 04:12:07 +0000 2019',
#   'id': 1197367060210126848,
#   'id_str': '1197367060210126848',
#   'text': 'RT @OfficerOLearyNZ: It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#      'indices': [40, 61]},
#     {'text': 'lyndatopp', 'indices': [62, 72]},
#     {'text': 'legend', 'indices': [73, 80]},
#     {'text': 'duckhunter', 'indices': [81, 92]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OfficerOLearyNZ',
#      'name': "Karen O'Leary",
#      'id': 1027084391292399617,
#      'id_str': '1027084391292399617',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1197010781646155776,
#      'id_str': '1197010781646155776',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'url': 'https://t.co/M3cD7mlDYm',
#      'display_url': 'pic.twitter.com/M3cD7mlDYm',
#      'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 453, 'resize': 'fit'}},
#      'source_status_id': 1197010788726145024,
#      'source_status_id_str': '1197010788726145024',
#      'source_user_id': 1027084391292399617,
#      'source_user_id_str': '1027084391292399617'}]},
#   'extended_entities': {'media': [{'id': 1197010781646155776,
#      'id_str': '1197010781646155776',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'url': 'https://t.co/M3cD7mlDYm',
#      'display_url': 'pic.twitter.com/M3cD7mlDYm',
#      'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 453, 'resize': 'fit'}},
#      'source_status_id': 1197010788726145024,
#      'source_status_id_str': '1197010788726145024',
#      'source_user_id': 1027084391292399617,
#      'source_user_id_str': '1027084391292399617'}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2437977996,
#    'id_str': '2437977996',
#    'name': 'Teresa Cowie',
#    'screen_name': 'teresacowienz',
#    'location': 'Wellington, New Zealand',
#    'description': 'Senior Specialist Journalist @radionz weekly news doco @InsightRNZ - Winner of Best Documentary NZ Radio Awards 2019 - Two wheels good 🚴\u200d♀️',
#    'url': 'https://t.co/B8UoBni9Nm',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/B8UoBni9Nm',
#        'expanded_url': 'http://www.radionz.co.nz/national/presenters/teresa-cowie',
#        'display_url': 'radionz.co.nz/national/prese…',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1317,
#    'friends_count': 1022,
#    'listed_count': 24,
#    'created_at': 'Fri Apr 11 05:20:38 +0000 2014',
#    'favourites_count': 3084,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 3090,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/926332571817881601/oBM7nCtM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/926332571817881601/oBM7nCtM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2437977996/1561375165',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 20 04:36:26 +0000 2019',
#    'id': 1197010788726145024,
#    'id_str': '1197010788726145024',
#    'text': 'It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#       'indices': [19, 40]},
#      {'text': 'lyndatopp', 'indices': [41, 51]},
#      {'text': 'legend', 'indices': [52, 59]},
#      {'text': 'duckhunter', 'indices': [60, 71]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1197010781646155776,
#       'id_str': '1197010781646155776',
#       'indices': [72, 95],
#       'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'url': 'https://t.co/M3cD7mlDYm',
#       'display_url': 'pic.twitter.com/M3cD7mlDYm',
#       'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1197010781646155776,
#       'id_str': '1197010781646155776',
#       'indices': [72, 95],
#       'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'url': 'https://t.co/M3cD7mlDYm',
#       'display_url': 'pic.twitter.com/M3cD7mlDYm',
#       'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1027084391292399617,
#     'id_str': '1027084391292399617',
#     'name': "Karen O'Leary",
#     'screen_name': 'OfficerOLearyNZ',
#     'location': 'Wellington City, New Zealand',
#     'description': "Hello. I am Karen O'Leary.  #wellingtonparanormal",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1668,
#     'friends_count': 109,
#     'listed_count': 4,
#     'created_at': 'Wed Aug 08 06:49:36 +0000 2018',
#     'favourites_count': 1256,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 88,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1027089173151281152/bsbb43dN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1027089173151281152/bsbb43dN_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1027084391292399617/1570069926',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 676,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 21,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 23:49:38 +0000 2019',
#   'id': 1197301003990765568,
#   'id_str': '1197301003990765568',
#   'text': "#WellingtonParanormal is not my type of comedy at all, yet it's one of the few things that genuinely makes me laugh… https://t.co/9wFElayeCJ",
#   'truncated': True,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [0, 21]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/9wFElayeCJ',
#      'expanded_url': 'https://twitter.com/i/web/status/1197301003990765568',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 340616362,
#    'id_str': '340616362',
#    'name': 'ⒷⓌ',
#    'screen_name': 'KOTDM1988',
#    'location': 'High Wycombe, England',
#    'description': '',
#    'url': 'https://t.co/4Dq1cgqrxK',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/4Dq1cgqrxK',
#        'expanded_url': 'http://www.sellfy.com/Empress_Pro',
#        'display_url': 'sellfy.com/Empress_Pro',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1536,
#    'friends_count': 1858,
#    'listed_count': 17,
#    'created_at': 'Sat Jul 23 00:22:41 +0000 2011',
#    'favourites_count': 23923,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 23271,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'AD7B55',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1178321640343650305/_UD0yy_0_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1178321640343650305/_UD0yy_0_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/340616362/1518562737',
#    'profile_link_color': 'FA743E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': 'FFFFFF',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 22:43:13 +0000 2019',
#   'id': 1197284286820257792,
#   'id_str': '1197284286820257792',
#   'text': 'Wtf #WellingtonParanormal is two seasons deep already?! Are the states gonna get the goods anytime soon?? @AJemaineClement @TaikaWaititi',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [4, 25]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AJemaineClement',
#      'name': 'Jemaine Clement',
#      'id': 23578176,
#      'id_str': '23578176',
#      'indices': [106, 122]},
#     {'screen_name': 'TaikaWaititi',
#      'name': 'Taika Waititi',
#      'id': 95610041,
#      'id_str': '95610041',
#      'indices': [123, 136]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 29359648,
#    'id_str': '29359648',
#    'name': 'phishboy',
#    'screen_name': 'DustinThenJames',
#    'location': 'Los Angeles, CA',
#    'description': 'Taste the fear. Tastes good on the bun.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 658,
#    'friends_count': 696,
#    'listed_count': 13,
#    'created_at': 'Tue Apr 07 02:38:28 +0000 2009',
#    'favourites_count': 5052,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 11632,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1172674682098769920/X7rgUu3v_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1172674682098769920/X7rgUu3v_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/29359648/1546992982',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 21:13:17 +0000 2019',
#   'id': 1197261656415301632,
#   'id_str': '1197261656415301632',
#   'text': 'So what do we need to do to get #WellingtonParanormal season 3 ??? @MrMikeMinogue @OfficerOLearyNZ',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [32, 53]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MrMikeMinogue',
#      'name': 'Mike Minogue',
#      'id': 68833930,
#      'id_str': '68833930',
#      'indices': [67, 81]},
#     {'screen_name': 'OfficerOLearyNZ',
#      'name': "Karen O'Leary",
#      'id': 1027084391292399617,
#      'id_str': '1027084391292399617',
#      'indices': [82, 98]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 43295184,
#    'id_str': '43295184',
#    'name': 'Sarah Miller',
#    'screen_name': 'kiwibookgirl',
#    'location': 'Auckland, new zealand',
#    'description': 'Book Lover - Loki Fangirl, enjoys supernatural, arrow, pop vinyls, superhero movies',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 398,
#    'friends_count': 400,
#    'listed_count': 9,
#    'created_at': 'Fri May 29 08:06:30 +0000 2009',
#    'favourites_count': 30786,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 24711,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'EDECE9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/621541820024000512/UrL_0ywU_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/621541820024000512/UrL_0ywU_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/43295184/1403074606',
#    'profile_link_color': '088253',
#    'profile_sidebar_border_color': 'D3D2CF',
#    'profile_sidebar_fill_color': 'E3E2DE',
#    'profile_text_color': '634047',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 20:47:32 +0000 2019',
#   'id': 1197255175544590337,
#   'id_str': '1197255175544590337',
#   'text': "#WellingtonParanormal keep introducing new loveable characters. I could watch a whole series of\n'The Vaping AI Flip-phone Robot'\n😅😅😅",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [0, 21]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2591958392,
#    'id_str': '2591958392',
#    'name': 'Diane Raiani🐦',
#    'screen_name': 'RaianiParr',
#    'location': 'Coromandel. NZ',
#    'description': 'Comm Artist*IT*📚👗🎭 vendor\n#politics #Literature #humanities #Eco🌱\n#FBR\nDissent expert. I used to be Right Wing.... in Hockey 😉',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 730,
#    'friends_count': 883,
#    'listed_count': 0,
#    'created_at': 'Fri Jun 27 20:53:52 +0000 2014',
#    'favourites_count': 23925,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4584,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1106687634456244224/11ih38AP_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1106687634456244224/11ih38AP_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2591958392/1572667422',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 19:56:59 +0000 2019',
#   'id': 1197242453352271872,
#   'id_str': '1197242453352271872',
#   'text': 'RT @OfficerOLearyNZ: It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#      'indices': [40, 61]},
#     {'text': 'lyndatopp', 'indices': [62, 72]},
#     {'text': 'legend', 'indices': [73, 80]},
#     {'text': 'duckhunter', 'indices': [81, 92]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OfficerOLearyNZ',
#      'name': "Karen O'Leary",
#      'id': 1027084391292399617,
#      'id_str': '1027084391292399617',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1197010781646155776,
#      'id_str': '1197010781646155776',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'url': 'https://t.co/M3cD7mlDYm',
#      'display_url': 'pic.twitter.com/M3cD7mlDYm',
#      'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 453, 'resize': 'fit'}},
#      'source_status_id': 1197010788726145024,
#      'source_status_id_str': '1197010788726145024',
#      'source_user_id': 1027084391292399617,
#      'source_user_id_str': '1027084391292399617'}]},
#   'extended_entities': {'media': [{'id': 1197010781646155776,
#      'id_str': '1197010781646155776',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'url': 'https://t.co/M3cD7mlDYm',
#      'display_url': 'pic.twitter.com/M3cD7mlDYm',
#      'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 453, 'resize': 'fit'}},
#      'source_status_id': 1197010788726145024,
#      'source_status_id_str': '1197010788726145024',
#      'source_user_id': 1027084391292399617,
#      'source_user_id_str': '1027084391292399617'}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 42286921,
#    'id_str': '42286921',
#    'name': 'Amie Mills',
#    'screen_name': 'AmieMills',
#    'location': 'Wellington City, New Zealand',
#    'description': 'I create. I find. I share. Head of Funding @NZonAir. Views pertain to me.',
#    'url': 'https://t.co/ZB3pnvyUDn',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/ZB3pnvyUDn',
#        'expanded_url': 'https://www.nzonair.govt.nz/',
#        'display_url': 'nzonair.govt.nz',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 989,
#    'friends_count': 389,
#    'listed_count': 34,
#    'created_at': 'Sun May 24 21:39:25 +0000 2009',
#    'favourites_count': 4034,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 6943,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'BADFCD',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/533557563023835136/BlYOj0Kt_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/533557563023835136/BlYOj0Kt_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/42286921/1416045139',
#    'profile_link_color': '0E0E8C',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'FFF7CC',
#    'profile_text_color': '0C3E53',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 20 04:36:26 +0000 2019',
#    'id': 1197010788726145024,
#    'id_str': '1197010788726145024',
#    'text': 'It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#       'indices': [19, 40]},
#      {'text': 'lyndatopp', 'indices': [41, 51]},
#      {'text': 'legend', 'indices': [52, 59]},
#      {'text': 'duckhunter', 'indices': [60, 71]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1197010781646155776,
#       'id_str': '1197010781646155776',
#       'indices': [72, 95],
#       'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'url': 'https://t.co/M3cD7mlDYm',
#       'display_url': 'pic.twitter.com/M3cD7mlDYm',
#       'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1197010781646155776,
#       'id_str': '1197010781646155776',
#       'indices': [72, 95],
#       'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'url': 'https://t.co/M3cD7mlDYm',
#       'display_url': 'pic.twitter.com/M3cD7mlDYm',
#       'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1027084391292399617,
#     'id_str': '1027084391292399617',
#     'name': "Karen O'Leary",
#     'screen_name': 'OfficerOLearyNZ',
#     'location': 'Wellington City, New Zealand',
#     'description': "Hello. I am Karen O'Leary.  #wellingtonparanormal",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1668,
#     'friends_count': 109,
#     'listed_count': 4,
#     'created_at': 'Wed Aug 08 06:49:36 +0000 2018',
#     'favourites_count': 1256,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 88,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1027089173151281152/bsbb43dN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1027089173151281152/bsbb43dN_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1027084391292399617/1570069926',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 676,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 21,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 19:00:35 +0000 2019',
#   'id': 1197228259823407104,
#   'id_str': '1197228259823407104',
#   'text': 'Still laughing at the "smells like a pineapple farted up my nose" line the next day 😂 #WellingtonParanormal https://t.co/IQTGexPere',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [86, 107]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1197228249761402881,
#      'id_str': '1197228249761402881',
#      'indices': [108, 131],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EJ1ov_4XUAEAd9g.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EJ1ov_4XUAEAd9g.jpg',
#      'url': 'https://t.co/IQTGexPere',
#      'display_url': 'pic.twitter.com/IQTGexPere',
#      'expanded_url': 'https://twitter.com/ParryKylie/status/1197228259823407104/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 438, 'h': 334, 'resize': 'fit'},
#       'medium': {'w': 438, 'h': 334, 'resize': 'fit'},
#       'small': {'w': 438, 'h': 334, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1197228249761402881,
#      'id_str': '1197228249761402881',
#      'indices': [108, 131],
#      'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EJ1ov_4XUAEAd9g.jpg',
#      'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EJ1ov_4XUAEAd9g.jpg',
#      'url': 'https://t.co/IQTGexPere',
#      'display_url': 'pic.twitter.com/IQTGexPere',
#      'expanded_url': 'https://twitter.com/ParryKylie/status/1197228259823407104/photo/1',
#      'type': 'animated_gif',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 438, 'h': 334, 'resize': 'fit'},
#       'medium': {'w': 438, 'h': 334, 'resize': 'fit'},
#       'small': {'w': 438, 'h': 334, 'resize': 'fit'}},
#      'video_info': {'aspect_ratio': [219, 167],
#       'variants': [{'bitrate': 0,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/tweet_video/EJ1ov_4XUAEAd9g.mp4'}]}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 351146900,
#    'id_str': '351146900',
#    'name': 'Xmas bumblebee',
#    'screen_name': 'ParryKylie',
#    'location': 'Entfarm, New Zealand',
#    'description': "Writer of children's stories and grower of trees. Optimistic past the point of reason. Loves elephant jokes & @Michael_J_Parry. She/her pronouns",
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 868,
#    'friends_count': 601,
#    'listed_count': 30,
#    'created_at': 'Mon Aug 08 21:16:35 +0000 2011',
#    'favourites_count': 28406,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 31175,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/911134422346350592/s0yz0Xkv_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/911134422346350592/s0yz0Xkv_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/351146900/1532734479',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 5,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 17:39:23 +0000 2019',
#   'id': 1197207825363197952,
#   'id_str': '1197207825363197952',
#   'text': 'RT @AJemaineClement: Love watching you guys live tweeting about #WellingtonParanormal\n\nThank you all for watching. \n\nThere will be new epis…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [64, 85]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AJemaineClement',
#      'name': 'Jemaine Clement',
#      'id': 23578176,
#      'id_str': '23578176',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 215608383,
#    'id_str': '215608383',
#    'name': 'krazyk182',
#    'screen_name': 'narika182',
#    'location': 'El paso tx',
#    'description': 'i make(^_^) youtube vids my channel is the same as my username. xbox diehard fan & 1day world dominator... owned by @dude_its_sebas',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 215,
#    'friends_count': 175,
#    'listed_count': 5,
#    'created_at': 'Sun Nov 14 12:24:09 +0000 2010',
#    'favourites_count': 7432,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 5443,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1183408431564296192/KuaVr855_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1183408431564296192/KuaVr855_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/215608383/1429676051',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 20 08:18:03 +0000 2019',
#    'id': 1197066563666493440,
#    'id_str': '1197066563666493440',
#    'text': 'Love watching you guys live tweeting about #WellingtonParanormal\n\nThank you all for watching. \n\nThere will be new e… https://t.co/JCDCvpf9mS',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#       'indices': [43, 64]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/JCDCvpf9mS',
#       'expanded_url': 'https://twitter.com/i/web/status/1197066563666493440',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 23578176,
#     'id_str': '23578176',
#     'name': 'Jemaine Clement',
#     'screen_name': 'AJemaineClement',
#     'location': 'New Zealand',
#     'description': 'What We Do In The Shadows: The Series playing now on FX\nWellington Paranormal - TVNZ  and SBS (Aus) on demand. \nFlight of the Conchords: Live in London on HBO.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 398827,
#     'friends_count': 1773,
#     'listed_count': 1482,
#     'created_at': 'Tue Mar 10 10:41:02 +0000 2009',
#     'favourites_count': 13942,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 16910,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/878855820183777280/Rm9i03Ml_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/878855820183777280/Rm9i03Ml_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23578176/1504657638',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 9,
#    'favorite_count': 448,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 9,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 17:34:19 +0000 2019',
#   'id': 1197206552278700035,
#   'id_str': '1197206552278700035',
#   'text': 'RT @AJemaineClement: #WellingtonParanormal is on the case. https://t.co/3fqt2QrXKj',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [21, 42]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AJemaineClement',
#      'name': 'Jemaine Clement',
#      'id': 23578176,
#      'id_str': '23578176',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1012255548887232514,
#      'id_str': '1012255548887232514',
#      'indices': [59, 82],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1012255548887232514/pu/img/BMNrtlL-Dwz_drUl.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1012255548887232514/pu/img/BMNrtlL-Dwz_drUl.jpg',
#      'url': 'https://t.co/3fqt2QrXKj',
#      'display_url': 'pic.twitter.com/3fqt2QrXKj',
#      'expanded_url': 'https://twitter.com/AJemaineClement/status/1012255863648739328/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1012255863648739328,
#      'source_status_id_str': '1012255863648739328',
#      'source_user_id': 23578176,
#      'source_user_id_str': '23578176'}]},
#   'extended_entities': {'media': [{'id': 1012255548887232514,
#      'id_str': '1012255548887232514',
#      'indices': [59, 82],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1012255548887232514/pu/img/BMNrtlL-Dwz_drUl.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1012255548887232514/pu/img/BMNrtlL-Dwz_drUl.jpg',
#      'url': 'https://t.co/3fqt2QrXKj',
#      'display_url': 'pic.twitter.com/3fqt2QrXKj',
#      'expanded_url': 'https://twitter.com/AJemaineClement/status/1012255863648739328/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_status_id': 1012255863648739328,
#      'source_status_id_str': '1012255863648739328',
#      'source_user_id': 23578176,
#      'source_user_id_str': '23578176',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 45000,
#       'variants': [{'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1012255548887232514/pu/pl/OYplHRcZd7C1v8j_.m3u8?tag=3'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
# ...
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/983991768071929856/9TDDURza_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/983991768071929856/9TDDURza_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/341977555/1523436898',
#    'profile_link_color': '009999',
#    'profile_sidebar_border_color': 'EEEEEE',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 3,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 07:33:10 +0000 2019',
#   'id': 1197055266040082432,
#   'id_str': '1197055266040082432',
#   'text': 'It would be salt &amp; pepper spray if it was for pies  #WellingtonParanormal',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'WellingtonParanormal',
#      'indices': [56, 77]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 28810147,
#    'id_str': '28810147',
#    'name': 'NickiJingles',
#    'screen_name': 'nickijingles',
#    'location': 'Christchurch City, New Zealand',
#    'description': 'Geek, Test/ IT/Web techie, philosopher, songwriter/composer, great at creating stuff, even greater at breaking stuff. NZ & UK',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 350,
#    'friends_count': 813,
#    'listed_count': 10,
#    'created_at': 'Sat Apr 04 15:19:03 +0000 2009',
#    'favourites_count': 9540,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4793,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '642D8B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1203519569/IMG_0007_normal.JPG',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1203519569/IMG_0007_normal.JPG',
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': '65B0DA',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 1,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 07:32:44 +0000 2019',
#   'id': 1197055157504098305,
#   'id_str': '1197055157504098305',
#   'text': 'Shhhhhhhh @OfficerOLearyNZ and @MrMikeMinogue are on! #wellingtonparanormal',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#      'indices': [54, 75]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OfficerOLearyNZ',
#      'name': "Karen O'Leary",
#      'id': 1027084391292399617,
#      'id_str': '1027084391292399617',
#      'indices': [10, 26]},
#     {'screen_name': 'MrMikeMinogue',
#      'name': 'Mike Minogue',
#      'id': 68833930,
#      'id_str': '68833930',
#      'indices': [31, 45]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 997628864770654208,
#    'id_str': '997628864770654208',
#    'name': 'Jonathon Hagger',
#    'screen_name': 'Awahouflow',
#    'location': 'Rotorua, Rotorua District',
#    'description': 'Chief Executive at Rotorua Community Hospice. Kaupapa Maori mental health advocate. #ngaitakato #NZL Also a sports fan and avid reader. Definitely an equalist.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 233,
#    'friends_count': 535,
#    'listed_count': 3,
#    'created_at': 'Sat May 19 00:03:51 +0000 2018',
#    'favourites_count': 9677,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1939,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1107929595196530693/B32WOT4i_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1107929595196530693/B32WOT4i_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/997628864770654208/1558575031',
#    'profile_link_color': '981CEB',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Wed Nov 20 07:27:41 +0000 2019',
#   'id': 1197053888228052998,
#   'id_str': '1197053888228052998',
#   'text': 'RT @OfficerOLearyNZ: It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#      'indices': [40, 61]},
#     {'text': 'lyndatopp', 'indices': [62, 72]},
#     {'text': 'legend', 'indices': [73, 80]},
#     {'text': 'duckhunter', 'indices': [81, 92]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'OfficerOLearyNZ',
#      'name': "Karen O'Leary",
#      'id': 1027084391292399617,
#      'id_str': '1027084391292399617',
#      'indices': [3, 19]}],
#    'urls': [],
#    'media': [{'id': 1197010781646155776,
#      'id_str': '1197010781646155776',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'url': 'https://t.co/M3cD7mlDYm',
#      'display_url': 'pic.twitter.com/M3cD7mlDYm',
#      'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 453, 'resize': 'fit'}},
#      'source_status_id': 1197010788726145024,
#      'source_status_id_str': '1197010788726145024',
#      'source_user_id': 1027084391292399617,
#      'source_user_id_str': '1027084391292399617'}]},
#   'extended_entities': {'media': [{'id': 1197010781646155776,
#      'id_str': '1197010781646155776',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#      'url': 'https://t.co/M3cD7mlDYm',
#      'display_url': 'pic.twitter.com/M3cD7mlDYm',
#      'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 453, 'resize': 'fit'}},
#      'source_status_id': 1197010788726145024,
#      'source_status_id_str': '1197010788726145024',
#      'source_user_id': 1027084391292399617,
#      'source_user_id_str': '1027084391292399617'}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 194331960,
#    'id_str': '194331960',
#    'name': "Joe O'Connor VO",
#    'screen_name': 'arjayo',
#    'location': 'Milton Keynes, UK, ZZ9 Plural',
#    'description': 'Voice Actor. Clients incl. I SPEAK MACHINE (@tarabusch @maflewis), @MychoPictures, @secklow1055fm, @rocket_cow; @GravyForBrain & @NetworkVO member.',
#    'url': 'https://t.co/epA9TxhtR8',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/epA9TxhtR8',
#        'expanded_url': 'https://soundcloud.com/joe-oconnor-2',
#        'display_url': 'soundcloud.com/joe-oconnor-2',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 781,
#    'friends_count': 2100,
#    'listed_count': 48,
#    'created_at': 'Thu Sep 23 21:46:40 +0000 2010',
#    'favourites_count': 51673,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 33308,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1194755730852712450/v04Gym1M_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1194755730852712450/v04Gym1M_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/194331960/1511527720',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Wed Nov 20 04:36:26 +0000 2019',
#    'id': 1197010788726145024,
#    'id_str': '1197010788726145024',
#    'text': 'It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'wellingtonparanormal',
#       'indices': [19, 40]},
#      {'text': 'lyndatopp', 'indices': [41, 51]},
#      {'text': 'legend', 'indices': [52, 59]},
#      {'text': 'duckhunter', 'indices': [60, 71]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1197010781646155776,
#       'id_str': '1197010781646155776',
#       'indices': [72, 95],
#       'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'url': 'https://t.co/M3cD7mlDYm',
#       'display_url': 'pic.twitter.com/M3cD7mlDYm',
#       'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1197010781646155776,
#       'id_str': '1197010781646155776',
#       'indices': [72, 95],
#       'media_url': 'http://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EJyi9sBU8AAo3NM.jpg',
#       'url': 'https://t.co/M3cD7mlDYm',
#       'display_url': 'pic.twitter.com/M3cD7mlDYm',
#       'expanded_url': 'https://twitter.com/OfficerOLearyNZ/status/1197010788726145024/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1620, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 800, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 453, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1027084391292399617,
#     'id_str': '1027084391292399617',
#     'name': "Karen O'Leary",
#     'screen_name': 'OfficerOLearyNZ',
#     'location': 'Wellington City, New Zealand',
#     'description': "Hello. I am Karen O'Leary.  #wellingtonparanormal",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1668,
#     'friends_count': 109,
#     'listed_count': 4,
#     'created_at': 'Wed Aug 08 06:49:36 +0000 2018',
#     'favourites_count': 1256,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 88,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1027089173151281152/bsbb43dN_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1027089173151281152/bsbb43dN_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1027084391292399617/1570069926',
#     'profile_link_color': 'FAB81E',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 21,
#    'favorite_count': 676,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 21,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'}]

# %% [markdown]
# The below scans through all of the retrieved tweets from our given hashtag search results and stores the tweet and tweet text in to two separate lists. Before adding, it checks if the tweet text exists already - if it does, the tweet is not added again. This avoids accumulating duplicates.

# %%
# DO NOT MODIFY

all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
        
print(len(filtered_statuses))
filtered_statuses[0].keys()
# Out:
# 87
# dict_keys(['created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'extended_entities', 'metadata', 'source', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'possibly_sensitive', 'lang'])

# %% [markdown]
# ## Exercise 5: Create a list of retweet count and status tuples
#
# We want to sort the tweets by the retweet count, therefore the first step is to create a list of **tuples** where the first element is the retweet count and then use the `sorted` function to perform the sorting operation.

# %%
retweets = None
### BEGIN SOLUTION
retweets = [(x['retweet_count'], x['text']) for x in filtered_statuses]
### END SOLUTION

# %%
assert len(retweets) == len(filtered_statuses), "Make sure you are using filterest_statuses and not statuses"
assert len(retweets[0]) == 2, "Each tuple should only have 2 elements, retweet count and the tweet text"

# %% [markdown]
# ## Exercise 6: Sort a list of tweets
#
# Use the built in Python `sorted` function to sort retweets and get the 10 more popular tweets (based on number of retweets). We'd like to have the more popular tweet first.

# %%
popular_tweets = None
### BEGIN SOLUTION
popular_tweets = sorted(retweets, reverse=True)[:10]
### END SOLUTION

popular_tweets
# Out:
# [(1919,
#   'RT @AJemaineClement: #WellingtonParanormal is on the case. https://t.co/3fqt2QrXKj'),
#  (21,
#   'RT @OfficerOLearyNZ: It’s me and me Mum #wellingtonparanormal #lyndatopp #legend #duckhunter https://t.co/M3cD7mlDYm'),
#  (9,
#   'RT @AJemaineClement: Love watching you guys live tweeting about #WellingtonParanormal\n\nThank you all for watching. \n\nThere will be new epis…'),
#  (9,
#   'Love watching you guys live tweeting about #WellingtonParanormal\n\nThank you all for watching. \n\nThere will be new e… https://t.co/JCDCvpf9mS'),
#  (7,
#   'RT @MrMikeMinogue: Tonight marks the end of season 2 of #wellingtonparanormal and we’re going out on a high. It’s been an absolute joy. See…'),
#  (1,
#   'Thank you team #WellingtonParanormal for another brilliant season over waaaaay too soon.'),
#  (1,
#   'RT @nickijingles: Thank you team #WellingtonParanormal for another brilliant season over waaaaay too soon.'),
#  (0,
#   'กุไม่น่าไปส่องแทกใน NZ เจออันนี้ขึ้นมาเลยเพิ่งรู้เนี่ยว่ามีซีรี่นี้ ฮืออออ อีบ้าอีบอมากแง 555555 #wellingtonparanormal'),
#  (0,
#   'Wtf #WellingtonParanormal is two seasons deep already?! Are the states gonna get the goods anytime soon?? @AJemaineClement @TaikaWaititi'),
#  (0,
#   "Why didn't they get Damo to make the virus?! #WellingtonParanormal #ShortlandStreet")]

# %%
assert len(popular_tweets) == 10, "Find the 10 most popular"
assert popular_tweets[0][0] >= popular_tweets[-1][0], "Make sure you are sorting in descending order"

# %% [markdown]
# <p style="font-family: Arial; font-size:3em;color:purple; font-style:bold"><br>
# Mini Project - Movie Ratings Over Time</p><br>
# <br>
#
# The aim of this project is to answer the following question:
#
# **Are movie ratings more biased at time of release, and do they become less one sided, and thus potentially more reasonable, over time?**
#
# The reason for this investigation is that I've noticed that some movies seem to have a far too high rating upon their release. I was curious if this is common across many movies and if the ratings tend to trend to a more reasonable rating over time.
#
# The dataset used is from the MovieLens website. It contains 20 million movie ratings applied to 27,000 movies by 138,000 users. The data was released in April 2015, and thus contains no ratings after this date. Below is a download link for the data
#
# Data Source: MovieLens web site (filename: ml-20m.zip)<br>
# Location: https://grouplens.org/datasets/movielens/

# %%
# %config IPCompleter.greedy=True

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('../Week-4-Pandas/movielens/movies.csv', sep=',')

# %%
print(movies.shape)
movies.head()
# Out:
# (27278, 3)
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# We can indicate time of release by year. We need to extract year from each movie's title and place it in to a new column 'year'. This is done using regular expressions and the Pandas `.str.extract()` method as below. We also don't need the genres column so lets take that out.

# %%
del(movies['genres'])
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)

# %%
movies.head()
# Out:
#    movieId                               title  year
# 0        1                    Toy Story (1995)  1995
# 1        2                      Jumanji (1995)  1995
# 2        3             Grumpier Old Men (1995)  1995
# 3        4            Waiting to Exhale (1995)  1995
# 4        5  Father of the Bride Part II (1995)  1995

# %%
ratings = pd.read_csv('../Week-4-Pandas/movielens/ratings.csv', sep=',')

# %%
print(ratings.shape)
ratings.head()
# Out:
# (20000263, 4)
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %% [markdown]
# We want to convert our rating timestamps from Unix time (seconds since 1 Jan 1970) to human readable time. This can be done by using the Pandas `.to_datetime()` method. We will put this in to new column 'datetime'. To keep things tidy, we'll also remove the previous 'timestamp' column.

# %%
ratings['datetime'] = pd.to_datetime(ratings['timestamp'], unit='s')
del(ratings['timestamp'])

# %%
ratings.head()
# Out:
#    userId  movieId  rating            datetime
# 0       1        2     3.5 2005-04-02 23:53:47
# 1       1       29     3.5 2005-04-02 23:31:16
# 2       1       32     3.5 2005-04-02 23:33:39
# 3       1       47     3.5 2005-04-02 23:32:07
# 4       1       50     3.5 2005-04-02 23:29:40

# %% [markdown]
# Using the `.min()` and `.max()` functions, we can see that our ratings data begins in 1995 and ends before 2016. Lets only consider movies 1995 and 2012. This allows us to take in to account the potentially more volatile year of release ratings, and the next few subsequent years ratings.

# %%
print(ratings['datetime'].min())
print(ratings['datetime'].max())
# Out:
# 1995-01-09 11:46:44
# 2015-03-31 06:40:02

# %% [markdown]
# We create a mask to filter out movies from 1995 to 2012.

# %%
m1 = movies['year'] >= '1995'
m2 = movies['year'] < '2013'

fmovies = movies[m1 & m2]

# %% [markdown]
# By putting the unique year values to a list - we can see there's problematic values (symbols) after the year value. Lets remove these.

# %%
movie_yrs = fmovies['year'].unique().tolist()
movie_yrs
# Out:
# ['1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2009– ',
#  '2007-']

# %%
fmovies['year'] = fmovies['year'].map(lambda x: x.rstrip(' -–'))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# Lets now convert the year in our movies dataframe to datetime. This allows it to be comparable to the rating timestamps in our ratings dataframe.

# %%
fmovies['year'] = pd.to_datetime(fmovies['year'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
fmovies.head()
# Out:
#    movieId                               title       year
# 0        1                    Toy Story (1995) 1995-01-01
# 1        2                      Jumanji (1995) 1995-01-01
# 2        3             Grumpier Old Men (1995) 1995-01-01
# 3        4            Waiting to Exhale (1995) 1995-01-01
# 4        5  Father of the Bride Part II (1995) 1995-01-01

# %% [markdown]
# A downside here is that all movies default to 1 Jan of the year of release. It would be better if we had release date of each movie in our dataset. This would allow a much more accurate analysis of the volatility of movie rating around time of release. Let's continue, acknowledging these limitations.
#
# Below we merge our two dataframes in to one by movieId, and assign to variable mvrt.

# %%
mvrt = ratings.merge(fmovies, on='movieId', how='inner')

# %%
mvrt.head()
# Out:
#    userId  movieId  rating            datetime           title       year
# 0       1        2     3.5 2005-04-02 23:53:47  Jumanji (1995) 1995-01-01
# 1       5        2     3.0 1996-12-25 15:26:09  Jumanji (1995) 1995-01-01
# 2      13        2     3.0 1996-11-27 08:19:02  Jumanji (1995) 1995-01-01
# 3      29        2     3.0 1996-06-23 20:36:14  Jumanji (1995) 1995-01-01
# 4      34        2     3.0 1996-10-28 13:29:44  Jumanji (1995) 1995-01-01

# %% [markdown]
# Pandas has the excellent ability to add and subtract values to timestamps using the `.DateOffset()` method. Using this, we can divide our ratings data in to two sets - a set containing ratings acquired only in the year of release, and a second set with all remaining ratings.

# %%
# Below is an example of how the pd.DateOffset() method works to add time to a given timestamp. 
# (1 year is offset from 1 Jan 1995, yielding us 1 Jan 1996).

print(mvrt['year'][0] + pd.DateOffset(years=1))
# Out:
# 1996-01-01 00:00:00

# %% [markdown]
# Below we create masks for ratings within the year of release, and ratings after the year of release. These are then assigned to dataframes 'yr_of_release' and 'subsequent' which we can compare to see if there is significant difference in the statistical data.

# %%
t_since_release = 1

early_ratings = mvrt['datetime'] < (mvrt['year'] + pd.DateOffset(years=t_since_release))
later_ratings = mvrt['datetime'] > (mvrt['year'] + pd.DateOffset(years=t_since_release))

yr_of_release = mvrt[early_ratings]
subsequent = mvrt[later_ratings]

# %% [markdown]
# When sorting the two dataframes by movieId below, we can see that some movies don't have any ratings made in the year of release. These will need to be removed from our subsequent ratings dataframe.
#
# In addition let's make a requirement for a minimum of 20 ratings in the year of release. This will hopefully avoid bias of too few ratings in the year of release skewing the data.

# %%
yr_of_release.sort_values(by='movieId', ascending=True)[:10]
# Out:
#          userId  movieId  rating            datetime  \
# 3049502  131160       21     3.0 1995-01-09 11:46:49
# 116714   131160       47     5.0 1995-01-09 11:46:49
# 5400377     928       61     2.0 1996-08-02 10:52:43
# 5401957   95223       61     5.0 1996-12-15 07:42:14
# 5401965   95910       61     5.0 1996-07-20 18:48:44
# 5401968   96165       61     3.0 1996-11-29 19:33:28
# 5401974   96664       61     3.0 1996-12-04 08:37:35
# 5401977   96878       61     4.0 1996-09-20 23:45:03
# 5401980   96974       61     4.0 1996-12-13 06:36:59
# 5401955   95186       61     4.0 1996-12-29 08:07:55
#
#                                title       year
# 3049502            Get Shorty (1995) 1995-01-01
# 116714   Seven (a.k.a. Se7en) (1995) 1995-01-01
# 5400377        Eye for an Eye (1996) 1996-01-01
# 5401957        Eye for an Eye (1996) 1996-01-01
# 5401965        Eye for an Eye (1996) 1996-01-01
# 5401968        Eye for an Eye (1996) 1996-01-01
# ...

# %%
subsequent.sort_values(by='movieId', ascending=True).head()
# Out:
#          userId  movieId  rating            datetime             title  \
# 1199895   69289        1     4.0 2011-08-30 14:36:47  Toy Story (1995)
# 1208235   92513        1     4.0 2005-09-28 04:15:11  Toy Story (1995)
# 1208236   92515        1     2.0 2004-04-02 14:53:59  Toy Story (1995)
# 1208237   92516        1     4.5 2003-05-22 16:41:36  Toy Story (1995)
# 1208238   92519        1     2.0 2001-10-05 21:32:36  Toy Story (1995)
#
#               year
# 1199895 1995-01-01
# 1208235 1995-01-01
# 1208236 1995-01-01
# 1208237 1995-01-01
# 1208238 1995-01-01

# %% [markdown]
# Let's create a Series containing only movieId's with a count of >19. Then we'll merge this with our existing dataframes to filter out any movies with fewer than 20 ratings in the year of release.

# %%
movie_count = yr_of_release[['movieId','rating']].groupby('movieId').count()

min_ratings_req = 19

m1 = movie_count['rating'] > min_ratings_req
more_ratings_movies = movie_count[m1]

# %% [markdown]
# When viewing the data below, we see the movieId and count of ratings. We can confirm all remaining movies have the minimum number of ratings we've specified.

# %%
more_ratings_movies[:10]
# Out:
#          rating
# movieId
# 61          602
# 63          252
# 64          599
# 65          712
# 66          523
# 70          962
# 74          939
# 75           95
# 79         1533
# 86          635

# %% [markdown]
# Before merging, we'll delete the column 'rating' as the count of each rating is not required for the merged datasets.

# %%
del(more_ratings_movies['rating'])

yr_of_release = yr_of_release.merge(more_ratings_movies, on='movieId', how='inner')
yr_of_release.head()
# Out:
#    userId  movieId  rating            datetime               title       year
# 0      29      653     3.0 1996-06-23 20:44:56  Dragonheart (1996) 1996-01-01
# 1      75      653     4.0 1996-07-02 13:04:16  Dragonheart (1996) 1996-01-01
# 2     149      653     4.0 1996-11-26 15:19:23  Dragonheart (1996) 1996-01-01
# 3     158      653     3.0 1996-09-14 21:06:52  Dragonheart (1996) 1996-01-01
# 4     159      653     3.0 1996-12-16 17:48:43  Dragonheart (1996) 1996-01-01

# %%
subsequent = subsequent.merge(more_ratings_movies, on='movieId', how='inner')
subsequent.head()
# Out:
#    userId  movieId  rating            datetime               title       year
# 0       1      653     3.0 2004-09-10 03:08:11  Dragonheart (1996) 1996-01-01
# 1       6      653     4.0 1997-03-13 17:54:18  Dragonheart (1996) 1996-01-01
# 2      11      653     4.5 2009-08-24 19:46:45  Dragonheart (1996) 1996-01-01
# 3      12      653     4.0 1997-03-22 20:50:25  Dragonheart (1996) 1996-01-01
# 4      39      653     3.0 1997-03-25 21:37:06  Dragonheart (1996) 1996-01-01

# %%
print('Year of release data has %d ratings, subsequent year data has %d ratings.' \
      % (len(yr_of_release), len(subsequent)))
# Out:
# Year of release data has 744722 ratings, subsequent year data has 6791058 ratings.

# %% [markdown]
# Great - there's now some consistency in our data! As can be seen above, the data contains the same movies, and the ratings are split by ratings in the year of release, and ratings from the years after. Now we can start the statistical analysis.
#
# To start, let's find the average rating per each movie in the two datasets. We can see that our data now contains 2,672 individual movies released from 1995-2012.

# %%
yor_avg = yr_of_release[['title', 'rating']].groupby('title').mean()
len(yor_avg)
# Out:
# 2672

# %%
sub_avg = subsequent[['title', 'rating']].groupby('title').mean()
len(sub_avg) == len(yor_avg)
# Out:
# True

# %%
yor_avg[-7:]
# Out:
#                                   rating
# title
# Zombie Strippers! (2008)        2.023256
# Zombieland (2009)               3.862445
# Zookeeper (2011)                2.300000
# Zoolander (2001)                3.274691
# eXistenZ (1999)                 3.258953
# xXx (2002)                      3.196078
# xXx: State of the Union (2005)  2.180921

# %%
sub_avg[-7:]
# Out:
#                                   rating
# title
# Zombie Strippers! (2008)        2.187023
# Zombieland (2009)               3.848723
# Zookeeper (2011)                2.308824
# Zoolander (2001)                3.254774
# eXistenZ (1999)                 3.338906
# xXx (2002)                      2.764516
# xXx: State of the Union (2005)  2.358293

# %% [markdown]
# Lets plot our data so we can visualize the difference between year of release ratings vs subsequent year ratings.

# %%
fig, ax = plt.subplots(figsize=(14, 8))

ax.plot(yor_avg[:], 'r-', label='Year of release ratings')
ax.plot(sub_avg[:], 'b-', label='Subsequent year ratings')
ax.set_ylabel('Ratings 1995-2015', fontsize=14)
ax.set_xlabel('Movies 1995-2012', fontsize=14)
ax.yaxis.grid(True)
ax.set_ylim(0.5, 5)

# below sets the x axis ticks to an empty list. (This hides the individual movie names)
ax.axes.get_xaxis().set_ticks([])

ax.set_title('Movie ratings over time comparison', fontsize=16)
legend = ax.legend(loc = 'lower right', shadow=False, prop={'weight':'roman','size':'large'})

plt.show()

# %% [markdown]
# Below we calculate the difference between average rating in year of release vs average rating in subsequent years for each of our movies. Using the `.describe()` method we can send that on average, movies in our dataset have a 0.054 higher rating in the year of release compared to subsequent ratings.
#
# The percentile ranges also show signs that year of release ratings tend to be higher - 25% of ratings are 0.191 higher in the year of release at the upper end, and at the bottom end, 25% of ratings are only 0.089 lower on year of release.

# %%
r_var = yor_avg['rating'] - sub_avg['rating']
r_var.sort_values(ascending=True)
r_var.describe()
# Out:
# count    2672.000000
# mean        0.054308
# std         0.257186
# min        -1.079475
# 25%        -0.089042
# 50%         0.049242
# 75%         0.191230
# max         2.033898
# Name: rating, dtype: float64

# %% [markdown]
# Below we display this data in a boxplot as a visual representation.

# %%
fig, ax = plt.subplots(figsize=(9, 7))

ax.boxplot(r_var[:], notch=True, vert=True,patch_artist=True)
ax.set_ylabel('Year of release rating - Subsequent year ratings', fontsize=12)
ax.yaxis.grid(True)

# below sets the x axis ticks to an empty list. (This hides the individual movie names)
ax.axes.get_xaxis().set_ticks([])
ax.set_ylim(-1.75, 1.75)

ax.set_title(
            'Difference between movie ratings at year of release vs subsequent ratings 1995-2012',
            fontsize=12
            )
plt.show()

# %% [markdown]
# While the difference is small, it does appear that movie ratings made in year of release show an upward bias. Further investigation in to particular years or for particular movies could show interesting results.
#
# We must ask ourselves why this is. Perhaps movie ratings change over time due to movies being too contemporary and dating quickly. Or could it be due to hype of movies upon release causing year of release ratings to be higher, while being lower in subsequent years once the hype is gone? Further investigation is required to answer these questions.

# %%
compare_ratings = yor_avg.merge(sub_avg, on='title', how='inner')
compare_ratings.rename(
                columns={"rating_x": "YoR_rating", "rating_y": "Subs_rating"}, inplace=True)

compare_ratings['difference'] = compare_ratings.iloc[:, 0] - compare_ratings.iloc[:, 1]

# %% [markdown]
# Below we can see the 10 movies that have decreased the most in rating since year of release. Not so surprising to see Titanic in there - it hasn't aged so well!

# %%
compare_ratings.sort_values('difference', ascending=False, inplace=True)
compare_ratings[:10]
# Out:
#                                       YoR_rating  Subs_rating  difference
# title
# Adrenalin: Fear the Rush (1996)         4.000000     1.966102    2.033898
# B*A*P*S (1997)                          3.365854     1.763441    1.602413
# Santa with Muscles (1996)               3.794118     2.328947    1.465170
# Substance of Fire, The (1996)           4.708333     3.388350    1.319984
# Sweet Nothing (1996)                    3.892857     2.692308    1.200549
# Albino Alligator (1996)                 4.043478     2.979973    1.063505
# Stupids, The (1996)                     3.162393     2.104118    1.058276
# 6th Man, The (Sixth Man, The) (1997)    3.571429     2.545775    1.025654
# Double Team (1997)                      3.127273     2.126891    1.000382
# Titanic (1997)                          4.307692     3.337014    0.970679

# %% [markdown]
# And here we see the 10 movies that have increased the most in rating since year of release.

# %%
compare_ratings[-10:]
# Out:
#                                            YoR_rating  Subs_rating  difference
# title
# Body Shots (1999)                            1.666667     2.406250   -0.739583
# Pootie Tang (2001)                           1.808511     2.604839   -0.796328
# Detroit Rock City (1999)                     2.355372     3.175733   -0.820361
# Light It Up (1999)                           2.000000     2.841346   -0.841346
# High School Musical 3: Senior Year (2008)    1.609756     2.452381   -0.842625
# Half Baked (1998)                            2.407895     3.306091   -0.898196
# Love Stinks (1999)                           1.739130     2.695946   -0.956816
# Perfect Man, The (2005)                      2.062500     3.026946   -0.964446
# Firehouse Dog (2007)                         1.800000     2.783333   -0.983333
# Hey Arnold! The Movie (2002)                 1.391304     2.470779   -1.079475

# %% [markdown]
# Finally below we can compare the movies that have been most consistent in rating against those that have been the most volatile.

# %%
compare_ratings.iloc[np.abs(compare_ratings['difference'].values).argsort()]
# Out:
#                                             YoR_rating  Subs_rating  \
# title
# Ides of March, The (2011)                     3.652000     3.651869
# Battlefield Earth (2000)                      1.600432     1.600570
# Greenberg (2010)                              3.220126     3.220395
# Life of Pi (2012)                             3.792135     3.791807
# Win a Date with Tad Hamilton! (2004)          2.861257     2.861616
# Get Over It (2001)                            3.030075     3.029703
# Lost and Delirious (2001)                     3.437500     3.437117
# Pursuit of Happyness, The (2006)              3.800000     3.800405
# End of Days (1999)                            2.635688     2.636095
# History of Violence, A (2005)                 3.637097     3.636631
# Tea with Mussolini (1999)                     3.400498     3.400990
# Whatever Works (2009)                         3.597403     3.597996
# Australia (2008)                              3.244186     3.244851
# ...

# %% [markdown]
# Below we plot the change in ratings in a frequency distribution. The slight bias towards higher ratings in year of release is easily noticeable here with a larger portion of the rating differences on the right (positive) side of the distribution.

# %%
import matplotlib.ticker as plticker

fig, ax = plt.subplots(figsize=(14, 8))

ax.hist(compare_ratings['difference'], bins=20)
ax.set_ylabel('Number of movies', fontsize=14)
ax.set_xlabel('Rating change (Year of release - subsequent years)', fontsize=14)
ax.grid(True)
ax.set_xlim(-1.5, 1.5)

# this locator puts ticks at regular intervals
loc = plticker.MultipleLocator(base=0.1) 
ax.xaxis.set_major_locator(loc)

loc = plticker.MultipleLocator(base=50) 
ax.yaxis.set_major_locator(loc)

plt.hist(compare_ratings['difference'], bins=35)
plt.show()

# %% [markdown]
# That concludes the mini project. Criticism or suggestions for further investigation are welcomed.
